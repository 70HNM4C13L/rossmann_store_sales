# %% [markdown]
# # 0.0 IMPORTS

# %%
import math
import warnings
import inflection
import random
import pickle
import numpy               as np
import pandas              as pd
import seaborn             as sns
import xgboost             as xgb
from matplotlib            import pyplot as plt
from IPython.core.display  import HTML
from IPython.display       import Image
from tabulate              import tabulate
from pycorrcat.pycorrcat   import plot_corr, corr_matrix
from sklearn.preprocessing import RobustScaler, MinMaxScaler,LabelEncoder
from sklearn.ensemble      import RandomForestRegressor
from sklearn.metrics       import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.linear_model  import LinearRegression, Lasso
from boruta                import BorutaPy

# %% [markdown]
# ## 0.1 HELPER FUNCTIONS

# %%
def cross_validation(x_training,kfold,model_name,model, verbose = False):
    mae_list = []
    mape_list = []
    rmse_list = []
    for k in range(kfold,0,-1):
        if verbose:
            print(f'kFold number:{k}')
        #start and end data validation
        validation_start_date = x_training['date'].max() - datetime.timedelta( days = k * 7 * 6)
        validation_end_date = x_training['date'].max() - datetime.timedelta( days = (k-1) * 7 * 6)

        #filtering dataset
        training = x_training[x_training['date'] < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        #training and validation dataset
        #training
        xtraining = training.drop(columns=['date','sales'])
        ytraining = training['sales']
        #validation
        xvalidation = validation.drop(columns=['date','sales'])
        yvalidation = validation['sales']
        #model
        m = model.fit(xtraining,ytraining)
        #predction
        yhat = m.predict (xvalidation)
        #performance
        m_result = ml_error('Linear Regression', np.expm1(yvalidation),np.expm1(yhat))
        # store performance of each kfold iteration
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])
    return pd.DataFrame({'Model Name' : model_name ,
                        'MAE_CROSS': np.round(np.mean(mae_list),2).astype( str ) + ' +- ' + np.round(np.std(mae_list),2).astype( str ) ,
                        'MAPE_CROSS': np.round(np.mean(mape_list),2).astype( str ) + ' +- '+ np.round(np.std(mape_list),2).astype( str ) ,
                        'RMSE_CROSS': np.round(np.mean(rmse_list),2).astype( str ) + ' +- ' + np.round(np.std(rmse_list),2).astype( str )}, index=[0])


def mean_percentage_error(y,yhat):
    return np.mean( ( y - yhat ) / y )


def ml_error(model_name,y,yhat):
    mae = mean_absolute_error (y,yhat)
    mape = mean_absolute_percentage_error (y,yhat)
    rmse = mean_squared_error (y,yhat)
    
    return pd.DataFrame({
        'Model Name': model_name,
        'MAE': mae,
        'MAPE' : mape,
        'RMSE' : np.sqrt(rmse)
    }, index = [0])


def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = 1000
    pd.options.display.max_rows = 1000
    pd.set_option( 'display.expand_frame_repr', False )    
    pd.set_option('display.float_format', lambda x: '%.3f' % x)
    sns.set()
    warnings.filterwarnings('ignore')

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/john/.pyenv/versions/3.10.5/envs/RossmanStoreSales/lib/python3.10/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 0.2 LOAD DATA

# %%
df_sales_raw = pd.read_csv('train.csv', low_memory=False)
df_store_raw = pd.read_csv('store.csv', low_memory=False)
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')
df_store_raw.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0      1         c          a             1270.000                      9.000                  2008.000       0              NaN              NaN              NaN
# 1      2         a          a              570.000                     11.000                  2007.000       1           13.000         2010.000  Jan,Apr,Jul,Oct
# 2      3         a          a            14130.000                     12.000                  2006.000       1           14.000         2011.000  Jan,Apr,Jul,Oct
# 3      4         c          c              620.000                      9.000                  2009.000       0              NaN              NaN              NaN
# 4      5         a          a            29910.000                      4.000                  2015.000       0              NaN              NaN              NaN

# %% [markdown]
# # 1.0 DATA DESCRIPT

# %%
df1 = df_raw.copy()
df1.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0      1          5  2015-07-31   5263        555     1      1            0              1         c          a             1270.000                      9.000                  2008.000       0              NaN              NaN              NaN
# 1      2          5  2015-07-31   6064        625     1      1            0              1         a          a              570.000                     11.000                  2007.000       1           13.000         2010.000  Jan,Apr,Jul,Oct
# 2      3          5  2015-07-31   8314        821     1      1            0              1         a          a            14130.000                     12.000                  2006.000       1           14.000         2011.000  Jan,Apr,Jul,Oct
# 3      4          5  2015-07-31  13995       1498     1      1            0              1         c          c              620.000                      9.000                  2009.000       0              NaN              NaN              NaN
# 4      5          5  2015-07-31   4822        559     1      1            0              1         a          a            29910.000                      4.000                  2015.000       0              NaN              NaN              NaN

# %% [markdown]
# ## 1.1 RENAME COLUMNS

# %%
df1.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday',
            'SchoolHoliday', 'StoreType', 'Assortment', 'CompetitionDistance',
            'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear',
            'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval']


def snakecase(x): 
    return inflection.underscore(x)


cols_new = list(map(snakecase, cols_old))
df1.columns = cols_new

# %% [markdown]
# ## 1.2 DATA DIMENSIONS

# %%
print(f'Number of rows {df1.shape[0]}')
print(f'Number of colunms {df1.shape[1]}')
# Out:
# Number of rows 1017209
# Number of colunms 18

# %% [markdown]
# ## 1.3 DATA TYPES

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4CHECK NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5 FILLOUT NA

# %%
month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
             7: 'Jul', 8: 'Aug', 9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000 if math.isnan(x)
                                                                else x)
df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan(x['competition_open_since_month']) else
                                                x['competition_open_since_month'], axis=1)
df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['competition_open_since_year']) else
                                               x['competition_open_since_year'], axis=1)
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week if math.isnan(x['promo2_since_week']) else
                                     x['promo2_since_week'], axis=1)
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['promo2_since_year']) else
                                     x['promo2_since_year'], axis=1)

df1['month_map'] = df1['date'].dt.month.map(month_map)
df1['promo_interval'].fillna(0, inplace=True)
df1['is_promo'] = df1[['month_map', 'promo_interval']].apply(lambda x: 0 if x['promo_interval'] == 0 else
                                                             1 if x['month_map'] in x['promo_interval'].split(',') else
                                                             0, axis=1)

# %% [markdown]
# ## 1.6 CHANGE TYPES

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(
    int)
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(
    int)
df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)
df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# %% [markdown]
# ## 1.7 DESCRIPTIVE STATISTICAL

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(
    exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 1.7.1 NUMERICAL ATTRIBUTES

# %%
# CENTRAL:  TENDENCY - MEAN - MEDIAN
# DISPERSION: STD, MIN, MAX, RANGE, SKEW, KURTOSIS
num_attributes.agg(["min", "max", "mean", "median",
                   "std", "skew", "kurtosis"]).T
# Out:
#                                   min        max     mean   median       std   skew  kurtosis
# store                           1.000   1115.000  558.430  558.000   321.909 -0.001    -1.201
# day_of_week                     1.000      7.000    3.998    4.000     1.997  0.002    -1.247
# sales                           0.000  41551.000 5773.819 5744.000  3849.926  0.641     1.778
# customers                       0.000   7388.000  633.146  609.000   464.412  1.599     7.092
# open                            0.000      1.000    0.830    1.000     0.376 -1.758     1.091
# promo                           0.000      1.000    0.382    0.000     0.486  0.488    -1.762
# school_holiday                  0.000      1.000    0.179    0.000     0.383  1.678     0.815
# competition_distance           20.000 200000.000 5935.443 2330.000 12547.653 10.242   147.790
# competition_open_since_month    1.000     12.000    6.787    7.000     3.311 -0.042    -1.233
# competition_open_since_year  1900.000   2015.000 2010.325 2012.000     5.516 -7.236   124.071
# promo2                          0.000      1.000    0.501    1.000     0.500 -0.002    -2.000
# promo2_since_week               1.000     52.000   23.619   22.000    14.310  0.179    -1.184
# promo2_since_year            2009.000   2015.000 2012.793 2013.000     1.663 -0.784    -0.210
# is_promo                        0.000      1.000    0.172    0.000     0.377  1.740     1.027

# %%
sns.displot(df1['competition_distance'])

# %% [markdown]
# ### 1.7.2 CATEGORICAL ATTRIBUTES

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] != 0)]
aux2 = df1[df1['sales'] != 0]
plt.subplot(1, 3, 1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)
plt.subplot(1, 3, 2)
sns.boxplot(x='store_type', y='sales', data=aux2)
plt.subplot(1, 3, 3)
sns.boxplot(x='assortment', y='sales', data=aux2)
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0 FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 HYPOTHESIS MIND MAP

# %%
Image('img/DAILY_STORES_SALE.png')

# %% [markdown]
# ## 2.2 CREATION OF HYPOTHESES

# %% [markdown]
# ### 2.2.1 STORE HYPOTHESES

# %% [markdown]
# **1** Stores with more employees sell more
# **2** Stores with the most inventory sell the most
# **3** Largest stores sell more
# **4** Smaller stores sell less
# **5** Stores with the Largest Assortment Sell More

# %% [markdown]
# ### 2.2.2 PRODUCT HYPOTHESES

# %% [markdown]
# **1** Stores that invest more in marketing sell more
# **2** Stores that display more products in their windows sell more
# **3** Stores with lower prices sell more
# **4** Stores with lower prices on products for longer sell more

# %% [markdown]
# ### 2.2.3 TEMPORAL HYPOTHESES

# %% [markdown]
# **1** Stores that have holidays sell less
# **2** Stores that open in the first 6 months should sell more
# **3** Stores that open on weekends should sell more

# %% [markdown]
# ### 2.2.4 FINAL LIST HYPOTHESES

# %% [markdown]
# **1** Stores with the Largest Assortment Sell More
# **2** Stores with close competitors should sell less
# **3** Stores with longer competitors should sell more
# **4** Stores with promotions active for longer should sell more
# **5** Stores with more days of promotions should sell more
# **6** Stores with more consecutive promotions should sell more
# **7** Stores open during the Christmas holiday should sell more
# **8** Stores should sell more over the years
# **9** Stores should sell more after the 10th of each month
# **10** Stores should sell more in the second half
# **11** Stores should sell less on weekends
# **12** Stores should sell less during school holidays

# %% [markdown]
# ## 2.3 FEATURE ENGINEERING

# %%
# year
df2['year'] = df2['date'].dt.year
# month
df2['month'] = df2['date'].dt.month
# day
df2['day'] = df2['date'].dt.day
# week of year
df2['week_of_year'] = df2['date'].dt.isocalendar().week
# year of week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')
# competition since
df2['competition_since'] = df2.apply(lambda x : datetime.datetime(year = x['competition_open_since_year'] , month = x['competition_open_since_month'], day=1), axis = 1)
df2['competition_since_month'] = (df2['date']-df2['competition_since']).apply(lambda x : int((x.days)/30))
# promo since
df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype( str )
df2['promo_since'] = df2['promo_since'].apply( lambda x : datetime.datetime.strptime(x + '-1','%Y-%W-%w')) - datetime.timedelta(days = 7)
df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] ) /7 ).apply(lambda x : x.days).astype( int )
# assortment
df2['assortment'] = df2['assortment'].apply(lambda x : 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended') 
# state holiday
df2['state_holiday'] = df2['state_holiday'].apply( lambda x : 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christimas' if x == 'c' else 'regular_day')

# %%
df2.head()
# Out:
#    store  day_of_week       date  sales  customers  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval month_map  is_promo  year  month  day  week_of_year year_week competition_since  competition_since_month promo_since  promo_time_week
# 0      1            5 2015-07-31   5263        555     1      1   regular_day               1          c      basic              1270.000                             9                         2008       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2008-09-01                       84  2015-07-27                0
# 1      2            5 2015-07-31   6064        625     1      1   regular_day               1          a      basic               570.000                            11                         2007       1                 13               2010  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2007-11-01                       94  2010-03-22              279
# 2      3            5 2015-07-31   8314        821     1      1   regular_day               1          a      basic             14130.000                            12                         2006       1                 14               2011  Jan,Apr,Jul,Oct       Jul         1  2015      7   31            31   2015-30        2006-12-01                      105  2011-03-28              226
# 3      4            5 2015-07-31  13995       1498     1      1   regular_day               1          c   extended               620.000                             9                         2009       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2009-09-01                       71  2015-07-27                0
# 4      5            5 2015-07-31   4822        559     1      1   regular_day               1          a      basic             29910.000                             4                         2015       0                 31               2015                0       Jul         0  2015      7   31            31   2015-30        2015-04-01                        4  2015-07-27                0

# %% [markdown]
# # 3.0 VARIABLE FILTERING

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 ROW SELECTION

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2 COLUMNS SELECTION

# %%
cols_drop = ['customers','open','promo_interval','month_map']
df3 = df3.drop(columns = cols_drop)

# %%
df3.head()
# Out:
#    store  day_of_week       date  sales  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year year_week competition_since  competition_since_month promo_since  promo_time_week
# 0      1            5 2015-07-31   5263      1   regular_day               1          c      basic              1270.000                             9                         2008       0                 31               2015         0  2015      7   31            31   2015-30        2008-09-01                       84  2015-07-27                0
# 1      2            5 2015-07-31   6064      1   regular_day               1          a      basic               570.000                            11                         2007       1                 13               2010         1  2015      7   31            31   2015-30        2007-11-01                       94  2010-03-22              279
# 2      3            5 2015-07-31   8314      1   regular_day               1          a      basic             14130.000                            12                         2006       1                 14               2011         1  2015      7   31            31   2015-30        2006-12-01                      105  2011-03-28              226
# 3      4            5 2015-07-31  13995      1   regular_day               1          c   extended               620.000                             9                         2009       0                 31               2015         0  2015      7   31            31   2015-30        2009-09-01                       71  2015-07-27                0
# 4      5            5 2015-07-31   4822      1   regular_day               1          a      basic             29910.000                             4                         2015       0                 31               2015         0  2015      7   31            31   2015-30        2015-04-01                        4  2015-07-27                0

# %% [markdown]
# # 4.0 EDA - EXPLORATORY DATA ANALYSIS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 UNIVARIATE ANALYSIS

# %% [markdown]
# ### 4.1.1 RESPONSE VARIABLE

# %%
sns.displot(df4['sales'], kde = False);

# %% [markdown]
# ### 4.1.2 NUMERICAL VARIABLE

# %%
num_attributes.hist(bins = 25);

# %% [markdown]
# ### 4.1.3 CATEGORICAL VARIABLE

# %%
#state_holiday
plt.subplot(3,2,1)
sns.countplot(df4[df4['state_holiday'] != 'regular_day']['state_holiday']);
plt.subplot(3,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label = 'public_holiday', shade = True);
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label = 'easter_holiday', shade = True);
sns.kdeplot(df4[df4['state_holiday'] == 'christimas']['sales'], label = 'christimas', shade = True);
plt.legend()

#store_type
plt.subplot(3,2,3)
sns.countplot(df4['store_type']);
plt.subplot(3,2,4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label = 'a', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label = 'b', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label = 'c', shade = True);
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label = 'd', shade = True);
plt.legend()

#assortment
plt.subplot(3,2,5)
sns.countplot(df4['assortment']);
plt.subplot(3,2,6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label = 'basic', shade = True);
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label = 'extended', shade = True);
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label = 'extra', shade = True);
plt.legend();

# %% [markdown]
# ## 4.2 BIVARIATE ANALYSIS

# %% [markdown]
# ### **H1** Stores with the Largest Assortment Sell More
# **FALSE** STORES WITH LARGEST ASSORTMENT SELL LESS

# %%
aux1 = df4[['assortment','sales']].groupby('assortment').sum().reset_index()
sns.barplot(data = aux1, x = 'assortment', y = 'sales');
aux2 = df4[['assortment','sales','year_week']].groupby(['year_week','assortment']).sum().reset_index()
aux2.pivot(index ='year_week' ,columns = 'assortment' ,values ='sales').plot();
aux3 = aux2[aux2['assortment'] == 'extra']
aux3.pivot(index ='year_week' ,columns = 'assortment' ,values ='sales').plot();

# %% [markdown]
# ### **H2** Stores with close competitors should sell less
# **FALSE** STORES WITH CLOSE COMPETITOR SELL MORE

# %%
aux1 = df4[['competition_distance','sales']].groupby('competition_distance').sum().reset_index()
bins = list(np.arange(0,20000,1000))
plt.subplot(1,3,1)
sns.scatterplot(data = aux1, x = 'competition_distance', y = 'sales');
aux1['competition_distance_binned'] = pd.cut( aux1['competition_distance'], bins = bins )
aux2 = aux1[['competition_distance_binned','sales']].groupby('competition_distance_binned').sum().reset_index()
plt.subplot(1,3,2)
sns.barplot(data = aux2, x = 'competition_distance_binned', y = 'sales');
plt.xticks(rotation = 90);
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method= 'pearson'), annot= True);

# %% [markdown]
# ### **H3** Stores with longer competitors should sell more
# **FALSE** Stores with longer competitors sell less

# %%
aux1 = df4[['competition_since_month',
              'sales']].groupby('competition_since_month').sum().reset_index()
aux2 = aux1[(aux1['competition_since_month'] < 120) & (aux1['competition_since_month'] != 0)]
plt.subplot(1,3,1);
sns.barplot(x='competition_since_month', y='sales', data=aux2);
plt.xticks(rotation=90);
plt.subplot(1,3,2)
sns.regplot(x='competition_since_month', y='sales', data=aux2);
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method = 'pearson'), annot= True);

# %% [markdown]
# ### H4 Stores with promotions active for longer should sell more
# **FALSE** Stores with active promotions sell less, after a certain time

# %%
aux1 = df4[['promo_time_week','sales']].groupby('promo_time_week').sum().reset_index()
aux2 = aux1[aux1['promo_time_week'] > 0]
aux3 = aux1[aux1['promo_time_week'] < 0]
grid = GridSpec(2,3)
plt.subplot(grid[0,0]);
sns.barplot(x= 'promo_time_week', y = 'sales', data = aux3);
plt.xticks(rotation = 90);
plt.subplot(grid[0,1]);
sns.regplot(x= 'promo_time_week', y = 'sales', data = aux3);
plt.subplot(grid[1,0]);
sns.barplot(x= 'promo_time_week', y = 'sales', data = aux2);
plt.xticks(rotation = 90);
plt.subplot(grid[1,1]);
sns.regplot(x= 'promo_time_week', y = 'sales', data = aux2);
plt.subplot(grid[:,2])
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### <s>H5 Stores with more days of promotions should sell more</s>

# %% [markdown]
# ### H6 Stores with more consecutive promotions should sell more
# **FALSE** Stores with consecutive promotions sell less

# %%
df4[['promo','promo2','sales']].groupby(['promo','promo2']).sum().reset_index()
# Out:
#    promo  promo2       sales
# 0      0       0  1482612096
# 1      0       1  1289362241
# 2      1       0  1628930532
# 3      1       1  1472275754

# %%
aux1 = df4[(df4['promo'] == 1) & (df4['promo2'] == 1)][['year_week','sales']].groupby('year_week').sum().reset_index()
ax = aux1.plot();
aux2 = df4[(df4['promo'] == 1) & (df4['promo2'] == 0)][['year_week','sales']].groupby('year_week').sum().reset_index()
aux2.plot(ax=ax);
ax.legend(labels = (['traditional and extended','extended']));

# %% [markdown]
# ### H7 Stores open during the Christmas holiday should sell more
# **FALSE** Stores opened during the Christmas holiday sell less

# %%
aux = df4[df4['state_holiday'] != 'regular_day']
aux1 = aux[['sales','state_holiday']].groupby('state_holiday').sum().reset_index()
plt.subplot(1,2,1)
sns.barplot(data = aux1, x='state_holiday', y='sales');
aux2 = aux[['year', 'sales', 'state_holiday']].groupby(['year', 'state_holiday']).sum().reset_index()
plt.subplot(1,2,2)
sns.barplot(data = aux2, x= 'year', y = 'sales', hue = 'state_holiday');

# %% [markdown]
# ### H8 Stores should sell more over the years
# **FALSE** Stores sell less over the years

# %%
aux1 = df4[['year','sales']].groupby('year').sum().reset_index()
plt.subplot(1,3,1)
sns.barplot(data = aux1, x= 'year', y = 'sales')
plt.subplot(1,3,2)
sns.regplot(data = aux1, x= 'year', y = 'sales')
plt.subplot(1,3,3)
sns.heatmap(aux1.corr( method = 'pearson'),annot=True);

# %% [markdown]
# ### H9 Stores should sell more after the 10th of each month
# **TRUE** Stores sell more after the 10th of each month

# %%
aux1 = df4[['day','sales']].groupby('day').sum().reset_index()

plt.subplot(2,2,1)
sns.barplot(data = aux1, x= 'day', y = 'sales')

plt.subplot(2,2,2)
sns.regplot(data = aux1, x= 'day', y = 'sales')

plt.subplot(2,2,3)
sns.heatmap(aux1.corr( method = 'pearson'),annot=True);

aux1['before_after'] = aux1['day'].apply( lambda x : 'before_day_10' if x <= 10 else 'after_day_10')
aux1 = aux1[['before_after', 'sales']].groupby('before_after').sum().reset_index()
plt.subplot(2,2,4)
sns.barplot( x='before_after', y = 'sales', data = aux1);

# %% [markdown]
# ### H10 Stores should sell more in the second half
# **TRUE** Stores sell more in the second half

# %%
aux1 = df4[df4['year']<2015][['month','sales']].groupby('month').sum().reset_index()
plt.subplot(1,3,1)
sns.barplot(data = aux1, x= 'month', y = 'sales')
plt.subplot(1,3,2)
sns.regplot(data = aux1, x= 'month', y = 'sales')
plt.subplot(1,3,3)
sns.heatmap(aux1.corr( method = 'pearson'),annot=True);

# %% [markdown]
# ### H11 Stores should sell less on weekends
# **TRUE** Stores sell less on weekends

# %%
aux1 = df4[['day_of_week','sales']].groupby('day_of_week').sum().reset_index()
plt.subplot(1,3,1)
sns.barplot(data = aux1, x= 'day_of_week', y = 'sales')
plt.subplot(1,3,2)
sns.regplot(data = aux1, x= 'day_of_week', y = 'sales')
plt.subplot(1,3,3)
sns.heatmap(aux1.corr( method = 'pearson'),annot=True);

# %% [markdown]
# ### H12 Stores should sell less during school holidays
# **TRUE** Stores sell less during school holidays

# %%
aux1 = df4[['school_holiday', 'sales']].groupby('school_holiday').sum().reset_index()
plt.subplot(2,1,1)
sns.barplot(data = aux1, x= 'school_holiday', y='sales');
aux2 = df4[['month','school_holiday', 'sales']].groupby(['month','school_holiday']).sum().reset_index()
plt.subplot(2,1,2)
sns.barplot(data = aux2, x = 'month', y= 'sales', hue = 'school_holiday')
# Out:
# <AxesSubplot:xlabel='month', ylabel='sales'>

# %% [markdown]
# ### 4.2.1 Summary of hypotheses

# %%
tab = [['hypotheses','conclusion', 'relevance'],
      ['H1','False','low'],
      ['H2','False','average'],
      ['H3','False','average'],
      ['H4','False','low'],
      ['H5','----','----'],
      ['H6','False','low'],
      ['H7','False','average'],
      ['H8','False','high'],
      ['H9','False','high'],
      ['H10','True','high'],
      ['H11','True','high'],
      ['H12','True','low']
      ]
print(tabulate(tab, headers='firstrow'))
# Out:
# hypotheses    conclusion    relevance
# ------------  ------------  -----------
# H1            False         low
# H2            False         average
# H3            False         average
# H4            False         low
# H5            ----          ----
# H6            False         low
# H7            False         average
# H8            False         high
# H9            False         high
# H10           True          high
# H11           True          high
# H12           True          low

# %% [markdown]
# ## 4.3 Multivariate analysis

# %% [markdown]
# ## 4.3.1 Numerical atributes

# %%
correlation_num = num_attributes.corr(method='pearson')
sns.heatmap(correlation_num, annot = True );

# %% [markdown]
# ## 4.3.2 Categorical atributes

# %%
cat_atributes = df4.select_dtypes( include = 'object' )
cat_atributes.head()
# Out:
#   state_holiday store_type assortment year_week
# 0   regular_day          c      basic   2015-30
# 1   regular_day          a      basic   2015-30
# 2   regular_day          a      basic   2015-30
# 3   regular_day          c   extended   2015-30
# 4   regular_day          a      basic   2015-30

# %%
correlation_matrix = corr_matrix(cat_atributes,['state_holiday','store_type','assortment'] )
sns.heatmap(correlation_matrix,annot=True);

# %% [markdown]
# # 5.0 DATA PREPARATION

# %%
df5 = df4.copy()
df5['week_of_year'] = df5['week_of_year'].astype(int64)
df5.head()
# Out:
#    store  day_of_week       date  sales  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year year_week competition_since  competition_since_month promo_since  promo_time_week
# 0      1            5 2015-07-31   5263      1   regular_day               1          c      basic              1270.000                             9                         2008       0                 31               2015         0  2015      7   31            31   2015-30        2008-09-01                       84  2015-07-27                0
# 1      2            5 2015-07-31   6064      1   regular_day               1          a      basic               570.000                            11                         2007       1                 13               2010         1  2015      7   31            31   2015-30        2007-11-01                       94  2010-03-22              279
# 2      3            5 2015-07-31   8314      1   regular_day               1          a      basic             14130.000                            12                         2006       1                 14               2011         1  2015      7   31            31   2015-30        2006-12-01                      105  2011-03-28              226
# 3      4            5 2015-07-31  13995      1   regular_day               1          c   extended               620.000                             9                         2009       0                 31               2015         0  2015      7   31            31   2015-30        2009-09-01                       71  2015-07-27                0
# 4      5            5 2015-07-31   4822      1   regular_day               1          a      basic             29910.000                             4                         2015       0                 31               2015         0  2015      7   31            31   2015-30        2015-04-01                        4  2015-07-27                0

# %% [markdown]
# ## 5.1 NORMALIZATION

# %% [markdown]
# ## 5.2 RESCALING

# %%
rs = RobustScaler()

mms = MinMaxScaler()

df5['competition_distance'] = rs.fit_transform(df5[['competition_distance'
                                                    ]].values)

pickle.dump(rs, open('parameter/competition_distance_scaler.pkl', 'wb'))

df5['competition_since_month'] = rs.fit_transform(
    df5[['competition_since_month']].values)

pickle.dump(rs, open('parameter/competition_since_month_scaler.pkl', 'wb'))

df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)
pickle.dump(mms, open('parameter/promo_time_week_scaler.pkl', 'wb'))

df5['year'] = mms.fit_transform(df5[['year']].values)
pickle.dump(mms, open('parameter/year_scaler.pkl', 'wb'))

# %% [markdown]
# ## 5.3 TRANSFORMATION

# %% [markdown]
# ### 5.3.1 ENCODING

# %%
#STATE_HOLIDAY - ONE HOT ENCODING
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

#STORE_TYPE - LABEL ENCODING
le = LabelEncoder()

df5['store_type'] = le.fit_transform(df5['store_type'])

pickle.dump(le, open('parameter/store_type_scaler.pkl', 'wb'))

#ASSORTMENT - ORDINAL ENCODING
assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
df5['assortment'] = df5['assortment'].map(assortment_dict)

# %%
df5.head()
# Out:
#    store  day_of_week       date  sales  promo  school_holiday  store_type  assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  month  day  week_of_year year_week competition_since  competition_since_month promo_since  promo_time_week  state_holiday_christimas  state_holiday_easter_holiday  state_holiday_public_holiday  state_holiday_regular_day
# 0      1            5 2015-07-31   5263      1               1           2           1                -0.171                             9                         2008       0                 31               2015         0 1.000      7   31            31   2015-30        2008-09-01                    0.919  2015-07-27            0.287                         0                             0                             0                          1
# 1      2            5 2015-07-31   6064      1               1           0           1                -0.284                            11                         2007       1                 13               2010         1 1.000      7   31            31   2015-30        2007-11-01                    1.054  2010-03-22            0.923                         0                             0                             0                          1
# 2      3            5 2015-07-31   8314      1               1           0           1                 1.903                            12                         2006       1                 14               2011         1 1.000      7   31            31   2015-30        2006-12-01                    1.203  2011-03-28            0.802                         0                             0                             0                          1
# 3      4            5 2015-07-31  13995      1               1           2           3                -0.276                             9                         2009       0                 31               2015         0 1.000      7   31            31   2015-30        2009-09-01                    0.743  2015-07-27            0.287                         0                             0                             0                          1
# 4      5            5 2015-07-31   4822      1               1           0           1                 4.448                             4                         2015       0                 31               2015         0 1.000      7   31            31   2015-30        2015-04-01                   -0.162  2015-07-27            0.287                         0                             0                             0                          1

# %% [markdown]
# ### 5.3.2 RESPONSE VARIABLE TRANSFORMATION

# %%
df5['sales'] = np.log1p(df5['sales'])

# %% [markdown]
# ### 5.3.3 NATURE TRANSFORMATION

# %%
# -- Cyclic Nature --
# day of week
df5['day_of_week_sin'] = df5['day_of_week'].apply(
    lambda x: np.sin(x * (2. * np.pi / 7)))
df5['day_of_week_cos'] = df5['day_of_week'].apply(
    lambda x: np.cos(x * (2. * np.pi / 7)))
# month
df5['month_sin'] = df5['month'].apply(lambda x: np.sin(x * (2. * np.pi / 12)))
df5['month_cos'] = df5['month'].apply(lambda x: np.cos(x * (2. * np.pi / 12)))
# day
df5['day_sin'] = df5['day'].apply(lambda x: np.sin(x * (2. * np.pi / 30)))
df5['day_cos'] = df5['day'].apply(lambda x: np.cos(x * (2. * np.pi / 30)))
# week of year
df5['week_of_year_sin'] = df5['week_of_year'].apply(
    lambda x: np.sin(x * (2. * np.pi / 52)))
df5['week_of_year_cos'] = df5['week_of_year'].apply(
    lambda x: np.cos(x * (2. * np.pi / 52)))

# %% [markdown]
# # 6.0 FEATURE SELECTION

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1 SPLIT DATAFRAME INTO TRAINING AND TEST DATASET

# %%
cols_drop = [
    'week_of_year', 'day', 'month', 'day_of_week', 'promo_since',
    'competition_since', 'year_week'
]
df6 = df6.drop(cols_drop, axis=1)

# TRAINING DATA SET
X_train = df6[df6['date'] < '2015-06-19']
y_train = X_train['sales']

# TEST DATASET
X_test = df6[df6['date'] >= '2015-06-19']
y_test = X_test['sales']

print(f'Training Min date = {X_train["date"].min()}')
print(f'Training Max date = {X_train["date"].max()}')
print(f'\nTest Min date = {X_test["date"].min()}')
print(f'Test Max date = {X_test["date"].max()}')
# Out:
# Training Min date = 2013-01-01 00:00:00
# Training Max date = 2015-06-18 00:00:00
#
# Test Min date = 2015-06-19 00:00:00
# Test Max date = 2015-07-31 00:00:00

# %%
X_test.head()
# Out:
#    store       date  sales  promo  school_holiday  store_type  assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year  is_promo  year  competition_since_month  promo_time_week  state_holiday_christimas  state_holiday_easter_holiday  state_holiday_public_holiday  state_holiday_regular_day  day_of_week_sin  day_of_week_cos  month_sin  month_cos  day_sin  day_cos  week_of_year_sin  week_of_year_cos
# 0      1 2015-07-31  8.569      1               1           2           1                -0.171                             9                         2008       0                 31               2015         0 1.000                    0.919            0.287                         0                             0                             0                          1           -0.975           -0.223     -0.500     -0.866    0.208    0.978            -0.568            -0.823
# 1      2 2015-07-31  8.710      1               1           0           1                -0.284                            11                         2007       1                 13               2010         1 1.000                    1.054            0.923                         0                             0                             0                          1           -0.975           -0.223     -0.500     -0.866    0.208    0.978            -0.568            -0.823
# 2      3 2015-07-31  9.026      1               1           0           1                 1.903                            12                         2006       1                 14               2011         1 1.000                    1.203            0.802                         0                             0                             0                          1           -0.975           -0.223     -0.500     -0.866    0.208    0.978            -0.568            -0.823
# 3      4 2015-07-31  9.547      1               1           2           3                -0.276                             9                         2009       0                 31               2015         0 1.000                    0.743            0.287                         0                             0                             0                          1           -0.975           -0.223     -0.500     -0.866    0.208    0.978            -0.568            -0.823
# 4      5 2015-07-31  8.481      1               1           0           1                 4.448                             4                         2015       0                 31               2015         0 1.000                   -0.162            0.287                         0                             0                             0                          1           -0.975           -0.223     -0.500     -0.866    0.208    0.978            -0.568            -0.823

# %% [markdown]
# ## 6.2 BORUTA AS FEATURE SELECTOR

# %%
# # Comment this code to save time. Boruta takes to long
# # TRAINING AND TEST DATA SET FOR BOTURA
# x_train_n = X_train.drop(columns=['date', 'sales'], axis=1).values
# y_train_n = y_train.values.ravel()

# #RANDOM FOREST REGRESSOR
# rf = RandomForestRegressor(n_jobs=-1)
# #BORUTA
# boruta = BorutaPy(
#     rf,
#     n_estimators=10,
#     verbose=2,
#     random_state=42,
# ).fit(x_train_n, y_train_n)

# %%
# # comment this code to save time. Boruta takes to long
# cols_selected = boruta.support_.tolist()
# x_train_fs = X_train.drop(['date', 'sales'], axis=1)
# cols_selected_boruta = x_train_fs.iloc[:, cols_selected].columns.tolist()
# cols_not_selected_boruta = list(
#     np.setdiff1d(x_train_fs.columns, cols_selected_boruta))

# %%
#  'cols_selected_boruta'
#  'store',
#  'promo',
#  'store_type',
#  'assortment',
#  'competition_distance',
#  'competition_open_since_month',
#  'competition_open_since_year',
#  'promo2',
#  'promo2_since_week',
#  'promo2_since_year',
#  'competition_since_month',
#  'promo_time_week',
#  'day_of_week_sin',
#  'day_of_week_cos',
#  'month_cos',
#  'day_sin',
#  'day_cos',
#  'week_of_year_cos'

# %% [markdown]
# ## 6.3 MANUAL FEATURE SELECTION

# %%
cols_selected_boruta = [
    'store', 'promo', 'store_type', 'assortment', 'competition_distance',
    'competition_open_since_month', 'competition_open_since_year', 'promo2',
    'promo2_since_week', 'promo2_since_year', 'competition_since_month',
    'promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 'month_cos',
    'month_sin', 'day_sin', 'day_cos', 'week_of_year_cos', 'week_of_year_sin'
]
# cols to add
feat_to_add = ['date', 'sales']

# final features
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)
cols_selected_boruta_full
# Out:
# ['store',
#  'promo',
#  'store_type',
#  'assortment',
#  'competition_distance',
#  'competition_open_since_month',
#  'competition_open_since_year',
#  'promo2',
#  'promo2_since_week',
#  'promo2_since_year',
#  'competition_since_month',
#  'promo_time_week',
#  'day_of_week_sin',
#  'day_of_week_cos',
#  'month_cos',
#  'month_sin',
#  'day_sin',
#  'day_cos',
#  'week_of_year_cos',
#  'week_of_year_sin',
#  'date',
#  'sales']

# %% [markdown]
# # 7.0 MACHINE LEARNING MODELLING

# %%
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

# Time series Data Preparation
x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1 AVERAGE MODEL

# %%
aux1 = x_test.copy()
aux1['sales'] = y_test.copy()

#prediction
aux2 = aux1[['store','sales']].groupby('store').mean().reset_index().rename( columns = {'sales' : 'predictions'})
aux1 = pd.merge(aux1, aux2, how = 'left', on = 'store')
yhat_baseline = aux1['predictions']

#performance
baseline = ml_error('Average Model', np.expm1(y_test), np.expm1(yhat_baseline))
baseline
# Out:
#       Model Name      MAE  MAPE     RMSE
# 0  Average Model 1354.800 0.206 1835.136

# %% [markdown]
# ## 7.2 LINEAR REGRESSION MODEL

# %%
# model
lr = LinearRegression().fit(x_train, y_train)

# prediction
yhat_lr = lr.predict (x_test)

# performance
lr_result = ml_error('Linear Regression',np.expm1(y_test), np.expm1(yhat_lr))

lr_result
# Out:
#           Model Name      MAE  MAPE     RMSE
# 0  Linear Regression 1867.950 0.293 2672.561

# %% [markdown]
# ### 7.2.1 LINEAR REGRESSION MODEL - CROSS VALIDATION

# %%
#model
model = LinearRegression()

# Cross Validation
lr_cross = cross_validation(x_training,5, 'Linear Regression',model)

#result
lr_cross
# Out:
#           Model Name         MAE_CROSS   MAPE_CROSS         RMSE_CROSS
# 0  Linear Regression  2082.56 +- 295.7  0.3 +- 0.02  2953.41 +- 467.93

# %% [markdown]
# ## 7.3 LINEAR REGRESSION MODEL REGULARIZED MODEL

# %%
# model
lrr = Lasso(alpha= 0.01).fit(x_train, y_train)

# prediction
yhat_lrr = lrr.predict (x_test)

# performance
lrr_result = ml_error('Linear Regression Regularized',np.expm1(y_test), np.expm1(yhat_lrr))

lrr_result
# Out:
#                       Model Name      MAE  MAPE     RMSE
# 0  Linear Regression Regularized 1891.705 0.289 2744.452

# %% [markdown]
# ### 7.3.1 LINEAR REGRESSION MODEL REGULARIZED MODEL - CROSS VALIDATION

# %%
#model
model = Lasso(alpha = 0.01)

# Cross Validation
lrr_cross = cross_validation(x_training,5, 'Lasso',model)

#result
lrr_cross
# Out:
#   Model Name         MAE_CROSS    MAPE_CROSS         RMSE_CROSS
# 0      Lasso  2116.38 +- 341.5  0.29 +- 0.01  3057.75 +- 504.26

# %% [markdown]
# ## 7.4 RANDOM FOREST REGRESSOR

# %%
# model
rf = RandomForestRegressor(n_estimators=10, n_jobs=-1,
                           random_state=42).fit(x_train, y_train)

# prediction
yhat_rf = rf.predict(x_test)

# performance
rf_result = ml_error('Random Forest Regressor', np.expm1(y_test),
                     np.expm1(yhat_rf))
rf_result
# Out:
#                 Model Name     MAE  MAPE     RMSE
# 0  Random Forest Regressor 721.793 0.106 1070.300

# %% [markdown]
# ### 7.4.1 RANDOM FOREST REGRESSOR - CROSS VALIDATION

# %%
#model
model = RandomForestRegressor(n_estimators=30, n_jobs=-1, random_state=42)

# Cross Validation
rf_cross = cross_validation(x_training, 5, 'Random Forest', model, True)

#result
rf_cross
# Out:
# kFold number:5
# kFold number:4
# kFold number:3
# kFold number:2
# kFold number:1
#       Model Name         MAE_CROSS    MAPE_CROSS        RMSE_CROSS
# 0  Random Forest  851.39 +- 222.41  0.12 +- 0.02  1277.12 +- 325.9

# %% [markdown]
# ## 7.5 XGBOOST

# %%
# model
model_xgb = xgb.XGBRegressor(objective='reg:squarederror',
                             n_estimators=2500,
                             eta=0.01,
                             max_depth=10,
                             subsample=0.7,
                             colsample_bytree=0.9,
                             tree_method='gpu_hist').fit(x_train, y_train)

# prediction
yhat_xgb = model_xgb.predict(x_test)

# performance
xgb_result = ml_error('XGBoost Regressor', np.expm1(y_test),
                      np.expm1(yhat_xgb))
xgb_result
# Out:
#           Model Name     MAE  MAPE    RMSE
# 0  XGBoost Regressor 646.797 0.094 949.715

# %% [markdown]
# ### 7.5.1 XGBOOST - CROSS VALIDATION

# %%
#model
model = xgb.XGBRegressor(objective='reg:squarederror',
                         n_estimators=2500,
                         eta=0.01,
                         max_depth=10,
                         subsample=0.7,
                         colsample_bytree=0.9,
                         tree_method='gpu_hist')

# Cross Validation
xgb_cross = cross_validation(x_training, 5, 'XGBOOST', model, True)

#result
xgb_cross
# Out:
# kFold number:5
# kFold number:4
# kFold number:3
# kFold number:2
# kFold number:1
#   Model Name         MAE_CROSS    MAPE_CROSS        RMSE_CROSS
# 0    XGBOOST  831.05 +- 134.22  0.12 +- 0.01  1201.0 +- 196.16

# %%
xgb_cross
# Out:
#   Model Name         MAE_CROSS    MAPE_CROSS        RMSE_CROSS
# 0    XGBOOST  831.05 +- 134.22  0.12 +- 0.01  1201.0 +- 196.16

# %% [markdown]
# ## 7.6 COMPARE MODEL PERFORMANCE

# %% [markdown]
# ### 7.6.1 SINGLE PERFORMANCE

# %%
compare_result = pd.concat([
    baseline,
    lr_result,
    lrr_result,
    rf_result,
    xgb_result,
]).sort_values('RMSE')
compare_result
# Out:
#                       Model Name      MAE  MAPE     RMSE
# 0              XGBoost Regressor  646.797 0.094  949.715
# 0        Random Forest Regressor  721.793 0.106 1070.300
# 0                  Average Model 1354.800 0.206 1835.136
# 0              Linear Regression 1867.950 0.293 2672.561
# 0  Linear Regression Regularized 1891.705 0.289 2744.452

# %% [markdown]
# ### 7.6.2 CROSS VALIDATION PERFORMANCE

# %%
compare_result_cross = pd.concat([
    lr_cross,
    lrr_cross,
    rf_cross,
    xgb_cross,
]).sort_values('RMSE_CROSS')
compare_result_cross
# Out:
#           Model Name         MAE_CROSS    MAPE_CROSS         RMSE_CROSS
# 0            XGBOOST  831.05 +- 134.22  0.12 +- 0.01   1201.0 +- 196.16
# 0      Random Forest  851.39 +- 222.41  0.12 +- 0.02   1277.12 +- 325.9
# 0  Linear Regression  2082.56 +- 295.7   0.3 +- 0.02  2953.41 +- 467.93
# 0              Lasso  2116.38 +- 341.5  0.29 +- 0.01  3057.75 +- 504.26

# %% [markdown]
# # 8.0 HYPERPARAMETER FINE TUNING

# %% [markdown]
# ## 8.1 RANDON SEARCH

# %%
param = {
    'n_estimators': [1500, 1700, 2500, 3000, 3500],
    'eta': [0.01, 0.03],
    'max_depth': [3, 5, 9],
    'subsample': [0.1, 0.5, 0.7],
    'colsample_bytree': [0.3, 0.7, 0.9],
    'min_child_weight': [3, 8, 15]
}
max_eval = 10

# %%
# # Comment this code to save time.
# final_result = pd.DataFrame()

# for i in range(max_eval):
#     hp = {k: random.sample(v,1)[0] for k,v in param.items()}
#     print(hp)

# # model
#     model_xgb = xgb.XGBRegressor(objective='reg:squarederror',
#                                  n_estimators=hp['n_estimators'],
#                                  eta=hp['eta'],
#                                  max_depth=hp['max_depth'],
#                                  subsample=hp['subsample'],
#                                  colsample_bytree=hp['colsample_bytree'],
#                                  min_child_weight=hp['min_child_weight'],
#                                  tree_method='gpu_hist')

# # performance
#     result = cross_validation(x_training, 5, 'XGBOOST', model_xgb, True)
#     final_result = pd.concat([final_result,result])
# final_result

# %% [markdown]
# ## 8.2 FINAL MODEL

# %%
param_tuned = {
    'n_estimators': 1500,
    'eta': 0.03,
    'max_depth': 9,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'min_child_weight': 3
}

# %%
# model
model_xgb_tuned = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=param_tuned['n_estimators'],
    eta=param_tuned['eta'],
    max_depth=param_tuned['max_depth'],
    subsample=param_tuned['subsample'],
    colsample_bytree=param_tuned['colsample_bytree'],
    min_child_weight=param_tuned['min_child_weight'],
    tree_method='gpu_hist').fit(x_train, y_train)

#prediction
yhat_xgb_tuned = model_xgb.predict(x_test)

#performance
ml_error('XGBoost',np.expm1(y_test), np.expm1(yhat_xgb_tuned))
# Out:
#   Model Name     MAE  MAPE    RMSE
# 0    XGBoost 646.797 0.094 949.715

# %%
#save trained model
pickle.dump(model_xgb_tuned, open('model_rossmann.pkl', 'wb'))

# %% [markdown]
# # 9.0 ERROR TRANSLATION AND INTERPRETATION

# %%
df9 = X_test [cols_selected_boruta_full]

#predictions
df9['sales'] = np.expm1(df9['sales'])
df9['predctions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1 BUSINESS PERFORMANCE

# %%
#sum of predctions
df91 = df9[['store','predctions']].groupby('store').sum().reset_index()

#MAE and MAPE
df9_aux1 = df9[['store','sales','predctions']].groupby('store').apply( lambda x : mean_absolute_error (x['sales'], x['predctions'])).reset_index().rename(columns = {0:'MAE'})
df9_aux2 = df9[['store','sales','predctions']].groupby('store').apply( lambda x : mean_absolute_percentage_error (x['sales'], x['predctions'])).reset_index().rename(columns = {0:'MAPE'})

#merge
df9_aux3 = pd.merge(df9_aux1,df9_aux2, how='inner', on = 'store')
df92 = pd.merge(df91, df9_aux3, how='inner', on = 'store')

#scenarios

df92['worst_scenario'] = df92['predctions'] - df92['MAE']
df92['best_scenario'] = df92['predctions'] + df92['MAE']

#order collumns
df92 = df92[['store', 'predctions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

sns.scatterplot( x = 'store', y = 'MAPE', data =df92);

# %% [markdown]
# ## 9.1 TOTAL PERFORMANCE

# %%
df93 = df92[['predctions', 'worst_scenario', 'best_scenario']].apply(lambda x : np.sum(x), axis = 0).reset_index().rename(columns={'index':'scenarios',0:'values'})
df93['values'] = df93['values'].map( 'U$ {:.2f}'.format)
df93
# Out:
#         scenarios           values
# 0      predctions  U$ 283458976.00
# 1  worst_scenario  U$ 282733903.80
# 2   best_scenario  U$ 284184061.14

# %% [markdown]
# ## 9.3 MACHINE LEARNING PERFORMANCE

# %%
df9['error'] = df9['sales'] - df9['predctions']
df9['error_rate'] = df9['predctions'] / df9['sales']

# %%
subplot(2,2,1)
sns.lineplot(x = 'date', y ='sales', data = df9, label= 'SALES')
sns.lineplot(x = 'date', y ='predctions', data = df9, label= 'PREDCTIONS')

subplot(2,2,2)
sns.lineplot( x= 'date', y='error_rate',data = df9)
plt.axhline(1, linestyle = '--')

subplot(2,2,3)
sns.distplot(df9['error'])

subplot(2,2,4)
sns.scatterplot(df9['predctions'], df9['error']);

# %% [markdown]
# # 10.0 DEPLOY MODEL TO PRODUCTION

# %% [markdown]
# ## 10.1 ROSSMAN CLASS

# %%
import pickle
import inflection
import pandas as pd
import numpy as np
import math
import datetime

class Rossmann(object):

    def __init__(self):
        self.home_path                      ='/home/john/Documents/repos/rossmann_store_sales/'
        self.competition_distance_scaler    = pickle.load( open ( self.home_path + 'parameter/competition_distance_scaler.pkl', 'rb') )
        self.competition_since_month_scaler = pickle.load( open ( self.home_path + 'parameter/competition_since_month_scaler.pkl', 'rb') )
        self.promo_time_week_scaler         = pickle.load( open ( self.home_path + 'parameter/promo_time_week_scaler.pkl', 'rb') )
        self.year_scaler                    = pickle.load( open ( self.home_path + 'parameter/year_scaler.pkl', 'rb') )
        self.store_type_scaler              = pickle.load( open ( self.home_path + 'parameter/store_type_scaler.pkl', 'rb'))
 
    def data_cleaning(self, df1):
        ## 1.1 RENAME COLUMNS        

        cols_old = [
            'Store', 'DayOfWeek', 'Date', 'Open',
            'Promo', 'StateHoliday', 'SchoolHoliday', 'StoreType',
            'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
            'Promo2SinceYear', 'PromoInterval'
        ]

        def snakecase(x):
            return inflection.underscore(x)

        cols_new = list(map(snakecase, cols_old))
        df1.columns = cols_new

        ## 1.3 DATA TYPES

        df1['date'] = pd.to_datetime(df1['date'])

        ## 1.5 FILLOUT NA

        month_map = {
            1: 'Jan',
            2: 'Feb',
            3: 'Mar',
            4: 'Apr',
            5: 'May',
            6: 'Jun',
            7: 'Jul',
            8: 'Aug',
            9: 'Sept',
            10: 'Oct',
            11: 'Nov',
            12: 'Dec'
        }
        df1['competition_distance'] = df1['competition_distance'].apply(
            lambda x: 200000 if math.isnan(x) else x)
        df1['competition_open_since_month'] = df1.apply(
            lambda x: x['date'].month
            if math.isnan(x['competition_open_since_month']) else x[
                'competition_open_since_month'],
            axis=1)
        df1['competition_open_since_year'] = df1.apply(
            lambda x: x['date'].year
            if math.isnan(x['competition_open_since_year']) else x[
                'competition_open_since_year'],
            axis=1)
        df1['promo2_since_week'] = df1.apply(
            lambda x: x['date'].week
            if math.isnan(x['promo2_since_week']) else x['promo2_since_week'],
            axis=1)
        df1['promo2_since_year'] = df1.apply(
            lambda x: x['date'].year
            if math.isnan(x['promo2_since_year']) else x['promo2_since_year'],
            axis=1)

        df1['month_map'] = df1['date'].dt.month.map(month_map)
        df1['promo_interval'].fillna(0, inplace=True)
        df1['is_promo'] = df1[['month_map', 'promo_interval']].apply(
            lambda x: 0 if x['promo_interval'] == 0 else 1
            if x['month_map'] in x['promo_interval'].split(',') else 0,
            axis=1)

        ## 1.6 CHANGE TYPES

        df1['competition_open_since_month'] = df1[
            'competition_open_since_month'].astype(int)
        df1['competition_open_since_year'] = df1[
            'competition_open_since_year'].astype(int)
        df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)
        df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)
        
        return df1
        
        
        
    def feature_engineering(self,df2):
        
        # year
        df2['year'] = df2['date'].dt.year
        # month
        df2['month'] = df2['date'].dt.month
        # day
        df2['day'] = df2['date'].dt.day
        # week of year
        df2['week_of_year'] = df2['date'].dt.isocalendar().week
        # year of week
        df2['year_week'] = df2['date'].dt.strftime('%Y-%W')
        # competition since
        df2['competition_since'] = df2.apply(lambda x : datetime.datetime(year = x['competition_open_since_year'] , month = x['competition_open_since_month'], day=1), axis = 1)
        df2['competition_since_month'] = (df2['date']-df2['competition_since']).apply(lambda x : int((x.days)/30))
        # promo since
        df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype( str )
        df2['promo_since'] = df2['promo_since'].apply( lambda x : datetime.datetime.strptime(x + '-1','%Y-%W-%w')) - datetime.timedelta(days = 7)
        df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] ) /7 ).apply(lambda x : x.days).astype( int )
        # assortment
        df2['assortment'] = df2['assortment'].apply(lambda x : 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended') 
        # state holiday
        df2['state_holiday'] = df2['state_holiday'].apply( lambda x : 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christimas' if x == 'c' else 'regular_day')

        ## 3.1 ROW SELECTION

        df2 = df2[(df3['open'] != 0) ]

        ## 3.2 COLUMNS SELECTION 

        cols_drop = ['open','promo_interval','month_map']
        df2 = df2.drop(columns = cols_drop)
        
        return df2

    
    
    def data_preparation(self, df5):
        df5['week_of_year'] = df5['week_of_year'].astype(int64)        

        df5['competition_distance'] = self.competition_distance_scaler.transform(df5[['competition_distance'
                                                            ]].values)

        df5['competition_since_month'] = self.competition_since_month_scaler.transform(
            df5[['competition_since_month']].values)      

        df5['promo_time_week'] = self.promo_time_week_scaler.transform(df5[['promo_time_week']].values)        

        df5['year'] = self.year_scaler.transform(df5[['year']].values)

        ### 5.3.1 ENCODING

        #STATE_HOLIDAY - ONE HOT ENCODING
        df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

        #STORE_TYPE - LABEL ENCODING

        df5['store_type'] = self.store_type_scaler.transform(df5['store_type'])


        #ASSORTMENT - ORDINAL ENCODING
        assortment_dict = {'basic': 1, 'extra': 2, 'extended': 3}
        df5['assortment'] = df5['assortment'].map(assortment_dict)


        ### 5.3.3 NATURE TRANSFORMATION

        # -- Cyclic Nature --
        # day of week
        df5['day_of_week_sin'] = df5['day_of_week'].apply(
            lambda x: np.sin(x * (2. * np.pi / 7)))
        df5['day_of_week_cos'] = df5['day_of_week'].apply(
            lambda x: np.cos(x * (2. * np.pi / 7)))
        # month
        df5['month_sin'] = df5['month'].apply(lambda x: np.sin(x * (2. * np.pi / 12)))
        df5['month_cos'] = df5['month'].apply(lambda x: np.cos(x * (2. * np.pi / 12)))
        # day
        df5['day_sin'] = df5['day'].apply(lambda x: np.sin(x * (2. * np.pi / 30)))
        df5['day_cos'] = df5['day'].apply(lambda x: np.cos(x * (2. * np.pi / 30)))
        # week of year
        df5['week_of_year_sin'] = df5['week_of_year'].apply(
            lambda x: np.sin(x * (2. * np.pi / 52)))
        df5['week_of_year_cos'] = df5['week_of_year'].apply(
            lambda x: np.cos(x * (2. * np.pi / 52)))
        cols_selected= [
        'store', 'promo', 'store_type', 'assortment', 'competition_distance',
        'competition_open_since_month', 'competition_open_since_year', 'promo2',
        'promo2_since_week', 'promo2_since_year', 'competition_since_month',
        'promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 'month_cos',
        'month_sin', 'day_sin', 'day_cos', 'week_of_year_cos', 'week_of_year_sin']
        
        return df5[cols_selected]
     
                 
    def get_predction(self, model, original_data, test_data) :
        #predction
        pred = model.predict ( test_data )
                  
         #join predcti in to the original data
        original_data['prediction'] = np.expm1( pred )
        return original_data.to_json(orient = 'records', date_format = 'iso')

# %% [markdown]
# ## 10.2 API HANDLER

# %%
import pickle
import pandas          as pd
from flask             import Flask, request, Response
from rossmann.Rossmann import Rossmann

#load model

pickle.load(open('/home/john/Documents/repos/rossmann_store_sales/model_rossmann.pkl', 'rb'))

app = Flask(__name__)

@app.route('/rossmann/predict', methods = ['POST'])
def rossmann_predict():
    test_json = request.get_json()
    if test_json: #there is data
        if isinstance(test_json, dict): #unique example
            test_raw =  pd.DataFrame (test_json, index = [0])
        else: #multiple example
            test_raw =  pd.DataFrame (test_json, columns = test_json[0].keys())
            
            
            
        #Instantiate Rossmann Class
        pipeline = Rossmann()
        
        #data cleaning
        df1 = pipeline.data_cleaning(test_raw)
        
        #feature enginereing
        df2 = pipeline.feature_engineering(df1)
        
        #data preparation
        df3 = pipeline.data_preparation(df2)
        #prediction
        df_response = pipeline.get_predction(model, test_raw, df3) 
        return df_response
            
    else:
        return Response('', status = 200, mimetype='application/json')
    
    
    

if __name__ == '__main__':
    app.run('0.0.0.0')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [46], in <cell line: 4>()
#       2 import pandas          as pd
#       3 from flask             import Flask, request, Response
# ----> 4 from rossmann.Rossmann import Rossmann
#       6 #load model
#       8 pickle.load(open('/home/john/Documents/repos/rossmann_store_sales/model_rossmann.pkl', 'rb'))
#
# ModuleNotFoundError: No module named 'rossmann'

# %% [markdown]
# ## 10.3 API TESTER

# %%
import requests

# %%
#loading test dataset
df10 = pd.read_csv('/home/john/Documents/repos/rossmann_store_sales/test.csv')

# %%
# merge test dataset + store
df_test = pd.merge(df10, df_store_raw, how='left', on='Store')

#choose store for predction
# df_test = df_test[df_test['Store'].isin( [23,22,24] ) ] 
 
#remove closed days
df_test = df_test[df_test['Open'] != 0]
# df_test = df_teste[~df_test['Open'].isnull()]
df_test = df_test.drop('Id', axis=1)

# %%
df_test.head()
# Out:
#    Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0      1          4  2015-09-17 1.000      1            0              0         c          a             1270.000                      9.000                  2008.000       0              NaN              NaN              NaN
# 1      3          4  2015-09-17 1.000      1            0              0         a          a            14130.000                     12.000                  2006.000       1           14.000         2011.000  Jan,Apr,Jul,Oct
# 2      7          4  2015-09-17 1.000      1            0              0         a          c            24000.000                      4.000                  2013.000       0              NaN              NaN              NaN
# 3      8          4  2015-09-17 1.000      1            0              0         a          a             7520.000                     10.000                  2014.000       0              NaN              NaN              NaN
# 4      9          4  2015-09-17 1.000      1            0              0         a          c             2030.000                      8.000                  2000.000       0              NaN              NaN              NaN

# %%
#convert dataframe to json
data =json.dumps(df_test.to_dict( orient= 'records'))

# %%
#API CALL

url = 'http://0.0.0.0:5000/rossmann/predict'
header = { 'Content-type': 'application/json' }
data = data

r = requests.post(url, data = data, headers = header )
print ('Status code{}'.format ( r.status_code ) )
# Out:
# Status code200

# %%
d1 =  pd.DataFrame(r.json(), columns=r.json()[0].keys())

# %%
d2 = d1[['store','prediction']].groupby('store').sum().reset_index()

# %%
for i in range(len(d2)):
        print( 'Store {} will sell US${:,.2f} in the next 6 weeks'.format(d2.loc[i,'store'], d2.loc[i,'prediction']))
# Out:
# Store 1 will sell US$180,859.39 in the next 6 weeks
# Store 3 will sell US$276,252.06 in the next 6 weeks
# Store 7 will sell US$381,050.86 in the next 6 weeks
# Store 8 will sell US$235,782.02 in the next 6 weeks
# Store 9 will sell US$297,291.36 in the next 6 weeks
# Store 10 will sell US$223,695.26 in the next 6 weeks
# Store 11 will sell US$308,594.51 in the next 6 weeks
# Store 12 will sell US$297,184.54 in the next 6 weeks
# Store 13 will sell US$191,344.42 in the next 6 weeks
# Store 14 will sell US$216,553.19 in the next 6 weeks
# Store 15 will sell US$278,131.53 in the next 6 weeks
# Store 16 will sell US$308,564.00 in the next 6 weeks
# Store 19 will sell US$260,606.84 in the next 6 weeks
# Store 20 will sell US$314,794.21 in the next 6 weeks
# Store 21 will sell US$220,588.51 in the next 6 weeks
# Store 22 will sell US$177,543.32 in the next 6 weeks
# Store 23 will sell US$230,528.09 in the next 6 weeks
# Store 24 will sell US$383,824.29 in the next 6 weeks
# Store 25 will sell US$425,968.83 in the next 6 weeks
# Store 27 will sell US$384,236.50 in the next 6 weeks
# Store 29 will sell US$316,865.54 in the next 6 weeks
# Store 30 will sell US$187,261.92 in the next 6 weeks
# Store 31 will sell US$236,796.31 in the next 6 weeks
# Store 32 will sell US$156,076.93 in the next 6 weeks
# Store 33 will sell US$333,652.37 in the next 6 weeks
# Store 35 will sell US$435,556.01 in the next 6 weeks
# Store 36 will sell US$360,456.60 in the next 6 weeks
# Store 38 will sell US$237,881.55 in the next 6 weeks
# Store 39 will sell US$212,971.55 in the next 6 weeks
# Store 40 will sell US$181,232.01 in the next 6 weeks
# Store 41 will sell US$239,903.09 in the next 6 weeks
# Store 42 will sell US$400,550.79 in the next 6 weeks
# Store 43 will sell US$248,957.64 in the next 6 weeks
# Store 45 will sell US$207,683.70 in the next 6 weeks
# Store 46 will sell US$207,979.88 in the next 6 weeks
# Store 47 will sell US$308,675.88 in the next 6 weeks
# Store 48 will sell US$149,139.70 in the next 6 weeks
# Store 49 will sell US$302,979.42 in the next 6 weeks
# Store 50 will sell US$175,030.95 in the next 6 weeks
# Store 51 will sell US$271,199.54 in the next 6 weeks
# Store 52 will sell US$257,685.22 in the next 6 weeks
# Store 53 will sell US$226,275.64 in the next 6 weeks
# Store 56 will sell US$316,311.95 in the next 6 weeks
# Store 58 will sell US$274,480.13 in the next 6 weeks
# Store 61 will sell US$197,841.55 in the next 6 weeks
# Store 62 will sell US$253,308.75 in the next 6 weeks
# Store 63 will sell US$283,397.53 in the next 6 weeks
# Store 64 will sell US$432,886.76 in the next 6 weeks
# Store 66 will sell US$237,336.85 in the next 6 weeks
# Store 67 will sell US$319,145.70 in the next 6 weeks
# Store 68 will sell US$307,195.62 in the next 6 weeks
# Store 69 will sell US$345,021.83 in the next 6 weeks
# Store 70 will sell US$263,594.02 in the next 6 weeks
# Store 71 will sell US$352,793.85 in the next 6 weeks
# Store 72 will sell US$177,030.14 in the next 6 weeks
# Store 73 will sell US$191,507.08 in the next 6 weeks
# Store 74 will sell US$244,852.36 in the next 6 weeks
# Store 75 will sell US$255,355.68 in the next 6 weeks
# Store 76 will sell US$371,270.26 in the next 6 weeks
# Store 77 will sell US$318,761.47 in the next 6 weeks
# Store 79 will sell US$208,867.43 in the next 6 weeks
# Store 80 will sell US$297,197.27 in the next 6 weeks
# Store 81 will sell US$275,576.03 in the next 6 weeks
# Store 82 will sell US$358,517.64 in the next 6 weeks
# Store 83 will sell US$156,700.84 in the next 6 weeks
# Store 84 will sell US$508,956.90 in the next 6 weeks
# Store 86 will sell US$193,126.51 in the next 6 weeks
# Store 89 will sell US$241,212.93 in the next 6 weeks
# Store 90 will sell US$335,340.32 in the next 6 weeks
# Store 91 will sell US$187,743.80 in the next 6 weeks
# Store 92 will sell US$247,375.65 in the next 6 weeks
# Store 93 will sell US$225,882.19 in the next 6 weeks
# Store 94 will sell US$288,683.33 in the next 6 weeks
# Store 98 will sell US$218,220.03 in the next 6 weeks
# Store 99 will sell US$219,377.50 in the next 6 weeks
# Store 100 will sell US$308,413.75 in the next 6 weeks
# Store 101 will sell US$292,801.54 in the next 6 weeks
# Store 102 will sell US$282,071.57 in the next 6 weeks
# Store 105 will sell US$196,507.07 in the next 6 weeks
# Store 107 will sell US$292,240.09 in the next 6 weeks
# Store 108 will sell US$472,750.95 in the next 6 weeks
# Store 109 will sell US$268,915.53 in the next 6 weeks
# Store 110 will sell US$201,450.29 in the next 6 weeks
# Store 111 will sell US$260,279.13 in the next 6 weeks
# Store 112 will sell US$241,871.06 in the next 6 weeks
# Store 113 will sell US$249,495.02 in the next 6 weeks
# Store 115 will sell US$313,942.48 in the next 6 weeks
# Store 117 will sell US$157,350.18 in the next 6 weeks
# Store 118 will sell US$317,586.40 in the next 6 weeks
# Store 119 will sell US$248,855.69 in the next 6 weeks
# Store 120 will sell US$267,686.18 in the next 6 weeks
# Store 122 will sell US$351,081.45 in the next 6 weeks
# Store 124 will sell US$179,252.74 in the next 6 weeks
# Store 126 will sell US$223,419.20 in the next 6 weeks
# Store 127 will sell US$208,847.21 in the next 6 weeks
# Store 128 will sell US$311,395.90 in the next 6 weeks
# Store 129 will sell US$326,469.91 in the next 6 weeks
# Store 130 will sell US$197,275.35 in the next 6 weeks
# Store 131 will sell US$199,576.29 in the next 6 weeks
# Store 132 will sell US$270,182.74 in the next 6 weeks
# Store 135 will sell US$240,223.42 in the next 6 weeks
# Store 136 will sell US$228,054.43 in the next 6 weeks
# Store 137 will sell US$263,500.06 in the next 6 weeks
# Store 139 will sell US$253,984.16 in the next 6 weeks
# Store 140 will sell US$305,097.76 in the next 6 weeks
# Store 141 will sell US$221,258.67 in the next 6 weeks
# Store 142 will sell US$180,748.44 in the next 6 weeks
# Store 143 will sell US$256,007.97 in the next 6 weeks
# Store 144 will sell US$322,360.25 in the next 6 weeks
# Store 145 will sell US$296,229.46 in the next 6 weeks
# Store 146 will sell US$336,698.32 in the next 6 weeks
# Store 147 will sell US$329,217.02 in the next 6 weeks
# Store 149 will sell US$215,753.50 in the next 6 weeks
# Store 150 will sell US$349,388.17 in the next 6 weeks
# Store 152 will sell US$221,148.26 in the next 6 weeks
# Store 153 will sell US$272,212.98 in the next 6 weeks
# Store 154 will sell US$353,759.63 in the next 6 weeks
# Store 155 will sell US$265,004.20 in the next 6 weeks
# Store 157 will sell US$388,235.27 in the next 6 weeks
# Store 158 will sell US$324,063.27 in the next 6 weeks
# Store 159 will sell US$311,751.44 in the next 6 weeks
# Store 160 will sell US$235,845.51 in the next 6 weeks
# Store 161 will sell US$295,430.10 in the next 6 weeks
# Store 162 will sell US$305,283.24 in the next 6 weeks
# Store 164 will sell US$234,291.24 in the next 6 weeks
# Store 165 will sell US$153,786.52 in the next 6 weeks
# Store 166 will sell US$233,618.70 in the next 6 weeks
# Store 168 will sell US$301,140.98 in the next 6 weeks
# Store 169 will sell US$239,089.69 in the next 6 weeks
# Store 170 will sell US$181,606.45 in the next 6 weeks
# Store 171 will sell US$318,689.65 in the next 6 weeks
# Store 172 will sell US$259,844.42 in the next 6 weeks
# Store 174 will sell US$235,189.45 in the next 6 weeks
# Store 175 will sell US$230,338.40 in the next 6 weeks
# Store 176 will sell US$204,540.03 in the next 6 weeks
# Store 179 will sell US$296,536.28 in the next 6 weeks
# Store 180 will sell US$288,016.99 in the next 6 weeks
# Store 181 will sell US$254,194.44 in the next 6 weeks
# Store 182 will sell US$216,818.54 in the next 6 weeks
# Store 183 will sell US$211,298.53 in the next 6 weeks
# Store 184 will sell US$268,547.57 in the next 6 weeks
# Store 186 will sell US$166,399.29 in the next 6 weeks
# Store 187 will sell US$247,724.64 in the next 6 weeks
# Store 188 will sell US$197,075.64 in the next 6 weeks
# Store 189 will sell US$325,003.72 in the next 6 weeks
# Store 190 will sell US$286,410.57 in the next 6 weeks
# Store 191 will sell US$253,088.40 in the next 6 weeks
# Store 192 will sell US$454,769.48 in the next 6 weeks
# Store 193 will sell US$211,256.12 in the next 6 weeks
# Store 194 will sell US$205,173.14 in the next 6 weeks
# Store 195 will sell US$436,110.02 in the next 6 weeks
# Store 197 will sell US$267,699.07 in the next 6 weeks
# Store 199 will sell US$331,875.88 in the next 6 weeks
# Store 200 will sell US$307,732.42 in the next 6 weeks
# Store 201 will sell US$205,986.70 in the next 6 weeks
# Store 202 will sell US$250,123.18 in the next 6 weeks
# Store 204 will sell US$231,142.32 in the next 6 weeks
# Store 206 will sell US$308,339.26 in the next 6 weeks
# Store 207 will sell US$426,508.23 in the next 6 weeks
# Store 209 will sell US$265,080.20 in the next 6 weeks
# Store 210 will sell US$128,740.88 in the next 6 weeks
# Store 212 will sell US$192,571.14 in the next 6 weeks
# Store 213 will sell US$342,684.88 in the next 6 weeks
# Store 214 will sell US$363,239.38 in the next 6 weeks
# Store 215 will sell US$240,926.90 in the next 6 weeks
# Store 216 will sell US$283,034.24 in the next 6 weeks
# Store 217 will sell US$191,431.64 in the next 6 weeks
# Store 218 will sell US$191,514.77 in the next 6 weeks
# Store 219 will sell US$124,572.06 in the next 6 weeks
# Store 220 will sell US$195,947.53 in the next 6 weeks
# Store 221 will sell US$250,978.16 in the next 6 weeks
# Store 224 will sell US$282,171.34 in the next 6 weeks
# Store 226 will sell US$269,066.18 in the next 6 weeks
# Store 227 will sell US$244,627.14 in the next 6 weeks
# Store 228 will sell US$328,926.17 in the next 6 weeks
# Store 229 will sell US$348,747.89 in the next 6 weeks
# Store 230 will sell US$297,516.66 in the next 6 weeks
# Store 231 will sell US$199,391.73 in the next 6 weeks
# Store 233 will sell US$369,706.54 in the next 6 weeks
# Store 234 will sell US$416,734.57 in the next 6 weeks
# Store 235 will sell US$224,336.98 in the next 6 weeks
# Store 238 will sell US$303,941.41 in the next 6 weeks
# Store 239 will sell US$213,189.21 in the next 6 weeks
# Store 241 will sell US$269,642.57 in the next 6 weeks
# Store 242 will sell US$158,554.44 in the next 6 weeks
# Store 243 will sell US$275,597.51 in the next 6 weeks
# Store 244 will sell US$210,575.44 in the next 6 weeks
# Store 245 will sell US$361,215.32 in the next 6 weeks
# Store 246 will sell US$274,135.15 in the next 6 weeks
# Store 247 will sell US$349,313.85 in the next 6 weeks
# Store 248 will sell US$337,545.76 in the next 6 weeks
# Store 249 will sell US$230,090.19 in the next 6 weeks
# Store 250 will sell US$335,690.58 in the next 6 weeks
# Store 251 will sell US$761,978.18 in the next 6 weeks
# Store 252 will sell US$408,964.76 in the next 6 weeks
# Store 253 will sell US$230,244.62 in the next 6 weeks
# Store 254 will sell US$127,728.81 in the next 6 weeks
# Store 255 will sell US$260,822.16 in the next 6 weeks
# Store 256 will sell US$356,399.37 in the next 6 weeks
# Store 258 will sell US$220,776.98 in the next 6 weeks
# Store 259 will sell US$581,149.87 in the next 6 weeks
# Store 262 will sell US$874,181.48 in the next 6 weeks
# Store 263 will sell US$182,483.88 in the next 6 weeks
# Store 265 will sell US$210,486.06 in the next 6 weeks
# Store 267 will sell US$342,525.58 in the next 6 weeks
# Store 268 will sell US$195,237.20 in the next 6 weeks
# Store 269 will sell US$310,136.17 in the next 6 weeks
# Store 272 will sell US$247,043.33 in the next 6 weeks
# Store 273 will sell US$294,843.87 in the next 6 weeks
# Store 274 will sell US$186,669.13 in the next 6 weeks
# Store 275 will sell US$256,395.05 in the next 6 weeks
# Store 277 will sell US$242,609.11 in the next 6 weeks
# Store 278 will sell US$290,782.36 in the next 6 weeks
# Store 279 will sell US$376,612.08 in the next 6 weeks
# Store 280 will sell US$254,290.49 in the next 6 weeks
# Store 281 will sell US$243,305.03 in the next 6 weeks
# Store 283 will sell US$282,253.71 in the next 6 weeks
# Store 284 will sell US$212,967.95 in the next 6 weeks
# Store 285 will sell US$210,725.50 in the next 6 weeks
# Store 287 will sell US$324,344.30 in the next 6 weeks
# Store 288 will sell US$214,087.21 in the next 6 weeks
# Store 289 will sell US$243,115.04 in the next 6 weeks
# Store 290 will sell US$276,633.77 in the next 6 weeks
# Store 294 will sell US$228,157.98 in the next 6 weeks
# Store 295 will sell US$235,072.34 in the next 6 weeks
# Store 296 will sell US$272,288.01 in the next 6 weeks
# Store 297 will sell US$268,495.58 in the next 6 weeks
# Store 298 will sell US$336,401.71 in the next 6 weeks
# Store 299 will sell US$363,531.18 in the next 6 weeks
# Store 300 will sell US$305,969.28 in the next 6 weeks
# Store 301 will sell US$227,535.20 in the next 6 weeks
# Store 302 will sell US$152,136.00 in the next 6 weeks
# Store 303 will sell US$254,764.10 in the next 6 weeks
# Store 304 will sell US$252,216.31 in the next 6 weeks
# Store 305 will sell US$240,851.26 in the next 6 weeks
# Store 306 will sell US$181,419.38 in the next 6 weeks
# Store 308 will sell US$341,779.16 in the next 6 weeks
# Store 309 will sell US$270,241.76 in the next 6 weeks
# Store 310 will sell US$376,093.62 in the next 6 weeks
# Store 311 will sell US$277,090.38 in the next 6 weeks
# Store 312 will sell US$222,928.92 in the next 6 weeks
# Store 314 will sell US$209,399.08 in the next 6 weeks
# Store 315 will sell US$188,726.80 in the next 6 weeks
# Store 316 will sell US$388,174.86 in the next 6 weeks
# Store 317 will sell US$207,242.49 in the next 6 weeks
# Store 319 will sell US$316,004.32 in the next 6 weeks
# Store 320 will sell US$591,960.13 in the next 6 weeks
# Store 323 will sell US$311,267.97 in the next 6 weeks
# Store 325 will sell US$266,428.85 in the next 6 weeks
# Store 326 will sell US$221,596.71 in the next 6 weeks
# Store 328 will sell US$179,574.06 in the next 6 weeks
# Store 329 will sell US$273,217.81 in the next 6 weeks
# Store 330 will sell US$169,520.81 in the next 6 weeks
# Store 331 will sell US$225,289.82 in the next 6 weeks
# Store 333 will sell US$402,457.60 in the next 6 weeks
# Store 334 will sell US$227,631.74 in the next 6 weeks
# Store 335 will sell US$612,022.40 in the next 6 weeks
# Store 336 will sell US$524,740.85 in the next 6 weeks
# Store 337 will sell US$216,097.66 in the next 6 weeks
# Store 338 will sell US$266,960.53 in the next 6 weeks
# Store 339 will sell US$216,094.52 in the next 6 weeks
# Store 340 will sell US$271,764.19 in the next 6 weeks
# Store 341 will sell US$229,092.73 in the next 6 weeks
# Store 342 will sell US$405,444.20 in the next 6 weeks
# Store 343 will sell US$294,520.38 in the next 6 weeks
# Store 344 will sell US$363,707.15 in the next 6 weeks
# Store 345 will sell US$178,727.22 in the next 6 weeks
# Store 346 will sell US$287,115.03 in the next 6 weeks
# Store 347 will sell US$213,984.70 in the next 6 weeks
# Store 348 will sell US$323,059.89 in the next 6 weeks
# Store 350 will sell US$264,153.48 in the next 6 weeks
# Store 351 will sell US$253,396.34 in the next 6 weeks
# Store 352 will sell US$267,784.80 in the next 6 weeks
# Store 353 will sell US$288,850.55 in the next 6 weeks
# Store 354 will sell US$342,850.98 in the next 6 weeks
# Store 355 will sell US$364,013.86 in the next 6 weeks
# Store 356 will sell US$251,910.22 in the next 6 weeks
# Store 358 will sell US$409,889.18 in the next 6 weeks
# Store 359 will sell US$276,037.80 in the next 6 weeks
# Store 362 will sell US$383,294.58 in the next 6 weeks
# Store 364 will sell US$198,778.65 in the next 6 weeks
# Store 365 will sell US$199,774.81 in the next 6 weeks
# Store 367 will sell US$224,802.82 in the next 6 weeks
# Store 368 will sell US$392,641.83 in the next 6 weeks
# Store 369 will sell US$264,960.03 in the next 6 weeks
# Store 370 will sell US$303,768.53 in the next 6 weeks
# Store 371 will sell US$287,170.44 in the next 6 weeks
# Store 372 will sell US$354,544.12 in the next 6 weeks
# Store 373 will sell US$191,697.18 in the next 6 weeks
# Store 377 will sell US$336,273.54 in the next 6 weeks
# Store 378 will sell US$275,157.08 in the next 6 weeks
# Store 379 will sell US$163,841.82 in the next 6 weeks
# Store 380 will sell US$538,618.24 in the next 6 weeks
# Store 383 will sell US$693,459.24 in the next 6 weeks
# Store 385 will sell US$285,612.95 in the next 6 weeks
# Store 386 will sell US$282,242.05 in the next 6 weeks
# Store 387 will sell US$351,429.88 in the next 6 weeks
# Store 388 will sell US$400,538.52 in the next 6 weeks
# Store 389 will sell US$424,055.43 in the next 6 weeks
# Store 391 will sell US$231,613.16 in the next 6 weeks
# Store 392 will sell US$284,109.97 in the next 6 weeks
# Store 393 will sell US$241,358.18 in the next 6 weeks
# Store 394 will sell US$335,053.62 in the next 6 weeks
# Store 395 will sell US$158,870.86 in the next 6 weeks
# Store 397 will sell US$234,644.30 in the next 6 weeks
# Store 398 will sell US$216,772.24 in the next 6 weeks
# Store 399 will sell US$228,582.41 in the next 6 weeks
# Store 403 will sell US$266,054.03 in the next 6 weeks
# Store 404 will sell US$195,907.48 in the next 6 weeks
# Store 405 will sell US$181,380.22 in the next 6 weeks
# Store 406 will sell US$281,546.11 in the next 6 weeks
# Store 407 will sell US$161,155.99 in the next 6 weeks
# Store 408 will sell US$186,783.97 in the next 6 weeks
# Store 409 will sell US$234,451.79 in the next 6 weeks
# Store 410 will sell US$266,674.35 in the next 6 weeks
# Store 411 will sell US$363,343.59 in the next 6 weeks
# Store 412 will sell US$341,014.07 in the next 6 weeks
# Store 413 will sell US$296,636.63 in the next 6 weeks
# Store 414 will sell US$262,740.19 in the next 6 weeks
# Store 415 will sell US$250,429.55 in the next 6 weeks
# Store 416 will sell US$430,027.42 in the next 6 weeks
# Store 417 will sell US$283,973.72 in the next 6 weeks
# Store 418 will sell US$206,196.45 in the next 6 weeks
# Store 420 will sell US$202,172.76 in the next 6 weeks
# Store 421 will sell US$381,343.86 in the next 6 weeks
# Store 422 will sell US$187,866.91 in the next 6 weeks
# Store 424 will sell US$285,113.35 in the next 6 weeks
# Store 425 will sell US$133,725.38 in the next 6 weeks
# Store 426 will sell US$198,415.00 in the next 6 weeks
# Store 427 will sell US$307,925.88 in the next 6 weeks
# Store 428 will sell US$235,427.49 in the next 6 weeks
# Store 429 will sell US$227,965.00 in the next 6 weeks
# Store 430 will sell US$353,556.23 in the next 6 weeks
# Store 431 will sell US$376,293.79 in the next 6 weeks
# Store 432 will sell US$431,163.24 in the next 6 weeks
# Store 433 will sell US$251,002.78 in the next 6 weeks
# Store 434 will sell US$387,853.74 in the next 6 weeks
# Store 435 will sell US$124,379.32 in the next 6 weeks
# Store 440 will sell US$208,121.02 in the next 6 weeks
# Store 441 will sell US$254,899.11 in the next 6 weeks
# Store 442 will sell US$175,080.91 in the next 6 weeks
# Store 445 will sell US$339,181.52 in the next 6 weeks
# Store 446 will sell US$202,659.18 in the next 6 weeks
# Store 447 will sell US$229,874.80 in the next 6 weeks
# Store 448 will sell US$341,298.19 in the next 6 weeks
# Store 449 will sell US$421,926.08 in the next 6 weeks
# Store 450 will sell US$341,190.76 in the next 6 weeks
# Store 451 will sell US$218,907.62 in the next 6 weeks
# Store 452 will sell US$190,955.89 in the next 6 weeks
# Store 453 will sell US$455,051.57 in the next 6 weeks
# Store 455 will sell US$312,209.68 in the next 6 weeks
# Store 456 will sell US$245,963.76 in the next 6 weeks
# Store 457 will sell US$216,584.83 in the next 6 weeks
# Store 458 will sell US$293,979.62 in the next 6 weeks
# Store 459 will sell US$360,866.03 in the next 6 weeks
# Store 461 will sell US$199,715.08 in the next 6 weeks
# Store 463 will sell US$244,409.40 in the next 6 weeks
# Store 465 will sell US$314,414.90 in the next 6 weeks
# Store 466 will sell US$312,402.34 in the next 6 weeks
# Store 467 will sell US$548,382.73 in the next 6 weeks
# Store 468 will sell US$240,509.67 in the next 6 weeks
# Store 470 will sell US$549,793.47 in the next 6 weeks
# Store 471 will sell US$264,642.55 in the next 6 weeks
# Store 472 will sell US$209,699.10 in the next 6 weeks
# Store 473 will sell US$140,885.43 in the next 6 weeks
# Store 475 will sell US$256,368.19 in the next 6 weeks
# Store 477 will sell US$239,578.67 in the next 6 weeks
# Store 481 will sell US$229,334.58 in the next 6 weeks
# Store 484 will sell US$309,869.01 in the next 6 weeks
# Store 485 will sell US$208,843.14 in the next 6 weeks
# Store 486 will sell US$170,330.41 in the next 6 weeks
# Store 487 will sell US$293,520.58 in the next 6 weeks
# Store 488 will sell US$155,970.65 in the next 6 weeks
# Store 490 will sell US$306,813.13 in the next 6 weeks
# Store 491 will sell US$282,724.50 in the next 6 weeks
# Store 492 will sell US$309,562.02 in the next 6 weeks
# Store 493 will sell US$330,237.80 in the next 6 weeks
# Store 495 will sell US$204,973.05 in the next 6 weeks
# Store 497 will sell US$355,314.37 in the next 6 weeks
# Store 498 will sell US$257,721.13 in the next 6 weeks
# Store 499 will sell US$226,242.88 in the next 6 weeks
# Store 500 will sell US$242,456.39 in the next 6 weeks
# Store 501 will sell US$205,977.80 in the next 6 weeks
# Store 502 will sell US$420,373.01 in the next 6 weeks
# Store 504 will sell US$266,262.54 in the next 6 weeks
# Store 505 will sell US$203,905.16 in the next 6 weeks
# Store 506 will sell US$271,806.04 in the next 6 weeks
# Store 507 will sell US$344,321.88 in the next 6 weeks
# Store 508 will sell US$283,622.65 in the next 6 weeks
# Store 509 will sell US$236,331.89 in the next 6 weeks
# Store 510 will sell US$326,126.99 in the next 6 weeks
# Store 511 will sell US$223,475.61 in the next 6 weeks
# Store 512 will sell US$280,289.28 in the next 6 weeks
# Store 514 will sell US$248,179.74 in the next 6 weeks
# Store 515 will sell US$353,357.89 in the next 6 weeks
# Store 516 will sell US$245,850.35 in the next 6 weeks
# Store 517 will sell US$237,735.90 in the next 6 weeks
# Store 518 will sell US$245,170.48 in the next 6 weeks
# Store 519 will sell US$216,357.20 in the next 6 weeks
# Store 520 will sell US$165,878.16 in the next 6 weeks
# Store 521 will sell US$209,090.31 in the next 6 weeks
# Store 522 will sell US$338,888.84 in the next 6 weeks
# Store 524 will sell US$361,281.43 in the next 6 weeks
# Store 527 will sell US$445,270.48 in the next 6 weeks
# Store 528 will sell US$429,064.22 in the next 6 weeks
# Store 529 will sell US$331,495.00 in the next 6 weeks
# Store 530 will sell US$283,078.50 in the next 6 weeks
# Store 531 will sell US$214,462.25 in the next 6 weeks
# Store 532 will sell US$431,586.26 in the next 6 weeks
# Store 533 will sell US$406,159.73 in the next 6 weeks
# Store 534 will sell US$294,328.56 in the next 6 weeks
# Store 535 will sell US$318,433.58 in the next 6 weeks
# Store 536 will sell US$324,176.22 in the next 6 weeks
# Store 537 will sell US$234,569.13 in the next 6 weeks
# Store 538 will sell US$156,122.86 in the next 6 weeks
# Store 539 will sell US$413,421.31 in the next 6 weeks
# Store 540 will sell US$263,638.54 in the next 6 weeks
# Store 541 will sell US$271,902.10 in the next 6 weeks
# Store 542 will sell US$245,653.00 in the next 6 weeks
# Store 543 will sell US$108,536.32 in the next 6 weeks
# Store 545 will sell US$433,984.33 in the next 6 weeks
# Store 547 will sell US$236,399.03 in the next 6 weeks
# Store 548 will sell US$228,047.43 in the next 6 weeks
# Store 549 will sell US$199,659.99 in the next 6 weeks
# Store 550 will sell US$260,668.39 in the next 6 weeks
# Store 551 will sell US$268,933.94 in the next 6 weeks
# Store 552 will sell US$294,505.56 in the next 6 weeks
# Store 553 will sell US$276,861.89 in the next 6 weeks
# Store 554 will sell US$208,724.60 in the next 6 weeks
# Store 555 will sell US$192,377.36 in the next 6 weeks
# Store 557 will sell US$173,166.98 in the next 6 weeks
# Store 558 will sell US$133,563.31 in the next 6 weeks
# Store 561 will sell US$281,358.13 in the next 6 weeks
# Store 562 will sell US$839,622.56 in the next 6 weeks
# Store 563 will sell US$199,789.48 in the next 6 weeks
# Store 564 will sell US$233,679.12 in the next 6 weeks
# Store 565 will sell US$266,042.36 in the next 6 weeks
# Store 566 will sell US$203,130.14 in the next 6 weeks
# Store 567 will sell US$205,259.62 in the next 6 weeks
# Store 568 will sell US$208,246.91 in the next 6 weeks
# Store 570 will sell US$165,628.01 in the next 6 weeks
# Store 571 will sell US$313,099.13 in the next 6 weeks
# Store 572 will sell US$280,231.54 in the next 6 weeks
# Store 573 will sell US$167,778.91 in the next 6 weeks
# Store 574 will sell US$348,664.42 in the next 6 weeks
# Store 575 will sell US$206,545.24 in the next 6 weeks
# Store 577 will sell US$197,880.34 in the next 6 weeks
# Store 578 will sell US$390,151.16 in the next 6 weeks
# Store 579 will sell US$331,936.06 in the next 6 weeks
# Store 580 will sell US$397,726.35 in the next 6 weeks
# Store 581 will sell US$208,806.41 in the next 6 weeks
# Store 582 will sell US$270,376.72 in the next 6 weeks
# Store 584 will sell US$193,065.69 in the next 6 weeks
# Store 585 will sell US$208,568.85 in the next 6 weeks
# Store 586 will sell US$602,950.72 in the next 6 weeks
# Store 587 will sell US$400,058.56 in the next 6 weeks
# Store 588 will sell US$259,443.46 in the next 6 weeks
# Store 589 will sell US$197,564.20 in the next 6 weeks
# Store 590 will sell US$222,119.44 in the next 6 weeks
# Store 591 will sell US$226,343.68 in the next 6 weeks
# Store 592 will sell US$179,184.25 in the next 6 weeks
# Store 593 will sell US$381,553.73 in the next 6 weeks
# Store 597 will sell US$214,438.71 in the next 6 weeks
# Store 598 will sell US$226,301.01 in the next 6 weeks
# Store 600 will sell US$293,492.83 in the next 6 weeks
# Store 601 will sell US$203,867.59 in the next 6 weeks
# Store 602 will sell US$249,108.53 in the next 6 weeks
# Store 603 will sell US$271,082.72 in the next 6 weeks
# Store 604 will sell US$286,281.64 in the next 6 weeks
# Store 605 will sell US$279,284.83 in the next 6 weeks
# Store 610 will sell US$179,385.30 in the next 6 weeks
# Store 611 will sell US$235,697.98 in the next 6 weeks
# Store 612 will sell US$266,202.85 in the next 6 weeks
# Store 615 will sell US$365,063.71 in the next 6 weeks
# Store 616 will sell US$330,384.31 in the next 6 weeks
# Store 618 will sell US$290,666.12 in the next 6 weeks
# Store 619 will sell US$168,824.42 in the next 6 weeks
# Store 620 will sell US$306,614.56 in the next 6 weeks
# Store 621 will sell US$231,075.97 in the next 6 weeks
# Store 622 will sell US$182,645.07 in the next 6 weeks
# Store 623 will sell US$273,852.93 in the next 6 weeks
# Store 624 will sell US$284,095.05 in the next 6 weeks
# Store 625 will sell US$260,638.14 in the next 6 weeks
# Store 627 will sell US$255,219.89 in the next 6 weeks
# Store 628 will sell US$256,342.53 in the next 6 weeks
# Store 629 will sell US$250,302.13 in the next 6 weeks
# Store 631 will sell US$234,260.53 in the next 6 weeks
# Store 632 will sell US$286,249.05 in the next 6 weeks
# Store 633 will sell US$282,982.47 in the next 6 weeks
# Store 636 will sell US$231,741.24 in the next 6 weeks
# Store 637 will sell US$340,480.45 in the next 6 weeks
# Store 638 will sell US$238,809.79 in the next 6 weeks
# Store 639 will sell US$185,951.70 in the next 6 weeks
# Store 640 will sell US$464,011.71 in the next 6 weeks
# Store 641 will sell US$234,172.16 in the next 6 weeks
# Store 642 will sell US$148,449.80 in the next 6 weeks
# Store 643 will sell US$313,029.32 in the next 6 weeks
# Store 644 will sell US$362,983.16 in the next 6 weeks
# Store 645 will sell US$411,476.10 in the next 6 weeks
# Store 646 will sell US$198,951.33 in the next 6 weeks
# Store 647 will sell US$237,582.85 in the next 6 weeks
# Store 650 will sell US$251,580.62 in the next 6 weeks
# Store 651 will sell US$299,260.05 in the next 6 weeks
# Store 653 will sell US$231,262.09 in the next 6 weeks
# Store 655 will sell US$355,870.32 in the next 6 weeks
# Store 656 will sell US$129,819.76 in the next 6 weeks
# Store 657 will sell US$244,399.38 in the next 6 weeks
# Store 658 will sell US$235,760.57 in the next 6 weeks
# Store 659 will sell US$216,960.00 in the next 6 weeks
# Store 660 will sell US$190,144.72 in the next 6 weeks
# Store 661 will sell US$285,054.33 in the next 6 weeks
# Store 662 will sell US$336,949.01 in the next 6 weeks
# Store 663 will sell US$233,241.82 in the next 6 weeks
# Store 665 will sell US$323,851.59 in the next 6 weeks
# Store 666 will sell US$275,356.49 in the next 6 weeks
# Store 667 will sell US$348,768.76 in the next 6 weeks
# Store 669 will sell US$197,122.05 in the next 6 weeks
# Store 670 will sell US$240,294.79 in the next 6 weeks
# Store 671 will sell US$255,541.17 in the next 6 weeks
# Store 673 will sell US$303,345.50 in the next 6 weeks
# Store 674 will sell US$330,818.26 in the next 6 weeks
# Store 675 will sell US$159,880.35 in the next 6 weeks
# Store 676 will sell US$400,887.38 in the next 6 weeks
# Store 677 will sell US$269,669.45 in the next 6 weeks
# Store 678 will sell US$284,483.36 in the next 6 weeks
# Store 680 will sell US$199,186.76 in the next 6 weeks
# Store 681 will sell US$150,983.32 in the next 6 weeks
# Store 684 will sell US$330,330.14 in the next 6 weeks
# Store 685 will sell US$231,534.53 in the next 6 weeks
# Store 687 will sell US$363,367.07 in the next 6 weeks
# Store 689 will sell US$265,452.40 in the next 6 weeks
# Store 690 will sell US$225,133.50 in the next 6 weeks
# Store 691 will sell US$325,573.26 in the next 6 weeks
# Store 692 will sell US$251,830.24 in the next 6 weeks
# Store 693 will sell US$258,133.42 in the next 6 weeks
# Store 694 will sell US$318,614.85 in the next 6 weeks
# Store 695 will sell US$221,363.87 in the next 6 weeks
# Store 696 will sell US$333,928.57 in the next 6 weeks
# Store 697 will sell US$413,383.04 in the next 6 weeks
# Store 699 will sell US$305,101.15 in the next 6 weeks
# Store 700 will sell US$186,965.29 in the next 6 weeks
# Store 701 will sell US$226,878.03 in the next 6 weeks
# Store 702 will sell US$171,456.47 in the next 6 weeks
# Store 703 will sell US$117,887.19 in the next 6 weeks
# Store 705 will sell US$321,923.05 in the next 6 weeks
# Store 706 will sell US$228,835.70 in the next 6 weeks
# Store 707 will sell US$337,718.90 in the next 6 weeks
# Store 710 will sell US$180,589.67 in the next 6 weeks
# Store 711 will sell US$243,887.84 in the next 6 weeks
# Store 712 will sell US$235,924.22 in the next 6 weeks
# Store 713 will sell US$393,603.58 in the next 6 weeks
# Store 714 will sell US$210,996.60 in the next 6 weeks
# Store 716 will sell US$223,282.94 in the next 6 weeks
# Store 717 will sell US$230,220.24 in the next 6 weeks
# Store 718 will sell US$249,419.08 in the next 6 weeks
# Store 719 will sell US$208,458.13 in the next 6 weeks
# Store 720 will sell US$302,337.71 in the next 6 weeks
# Store 721 will sell US$314,662.01 in the next 6 weeks
# Store 722 will sell US$382,042.70 in the next 6 weeks
# Store 723 will sell US$319,056.71 in the next 6 weeks
# Store 724 will sell US$288,127.80 in the next 6 weeks
# Store 725 will sell US$240,288.12 in the next 6 weeks
# Store 727 will sell US$178,723.56 in the next 6 weeks
# Store 728 will sell US$204,846.38 in the next 6 weeks
# Store 729 will sell US$428,880.64 in the next 6 weeks
# Store 731 will sell US$352,794.33 in the next 6 weeks
# Store 732 will sell US$351,305.30 in the next 6 weeks
# Store 733 will sell US$713,690.23 in the next 6 weeks
# Store 734 will sell US$224,131.40 in the next 6 weeks
# Store 736 will sell US$201,423.33 in the next 6 weeks
# Store 737 will sell US$244,600.25 in the next 6 weeks
# Store 738 will sell US$346,947.22 in the next 6 weeks
# Store 739 will sell US$404,023.92 in the next 6 weeks
# Store 740 will sell US$277,735.24 in the next 6 weeks
# Store 741 will sell US$316,862.71 in the next 6 weeks
# Store 742 will sell US$329,704.76 in the next 6 weeks
# Store 744 will sell US$292,302.72 in the next 6 weeks
# Store 746 will sell US$273,416.23 in the next 6 weeks
# Store 748 will sell US$227,090.16 in the next 6 weeks
# Store 749 will sell US$199,486.66 in the next 6 weeks
# Store 750 will sell US$200,687.97 in the next 6 weeks
# Store 751 will sell US$165,243.71 in the next 6 weeks
# Store 752 will sell US$206,222.13 in the next 6 weeks
# Store 753 will sell US$332,931.17 in the next 6 weeks
# Store 756 will sell US$672,657.41 in the next 6 weeks
# Store 757 will sell US$266,538.82 in the next 6 weeks
# Store 758 will sell US$198,855.72 in the next 6 weeks
# Store 759 will sell US$294,548.41 in the next 6 weeks
# Store 762 will sell US$174,510.94 in the next 6 weeks
# Store 763 will sell US$259,506.48 in the next 6 weeks
# Store 764 will sell US$150,701.55 in the next 6 weeks
# Store 765 will sell US$355,250.88 in the next 6 weeks
# Store 766 will sell US$249,084.79 in the next 6 weeks
# Store 767 will sell US$251,757.81 in the next 6 weeks
# Store 768 will sell US$526,260.48 in the next 6 weeks
# Store 769 will sell US$564,721.55 in the next 6 weeks
# Store 770 will sell US$220,151.16 in the next 6 weeks
# Store 771 will sell US$264,900.87 in the next 6 weeks
# Store 772 will sell US$152,668.69 in the next 6 weeks
# Store 773 will sell US$214,603.52 in the next 6 weeks
# Store 774 will sell US$229,482.27 in the next 6 weeks
# Store 775 will sell US$341,119.40 in the next 6 weeks
# Store 776 will sell US$191,154.47 in the next 6 weeks
# Store 777 will sell US$186,773.96 in the next 6 weeks
# Store 778 will sell US$225,499.92 in the next 6 weeks
# Store 782 will sell US$229,930.18 in the next 6 weeks
# Store 784 will sell US$277,450.16 in the next 6 weeks
# Store 785 will sell US$283,877.49 in the next 6 weeks
# Store 789 will sell US$150,651.16 in the next 6 weeks
# Store 790 will sell US$301,456.39 in the next 6 weeks
# Store 791 will sell US$326,866.57 in the next 6 weeks
# Store 792 will sell US$294,071.37 in the next 6 weeks
# Store 793 will sell US$192,220.16 in the next 6 weeks
# Store 795 will sell US$174,366.02 in the next 6 weeks
# Store 796 will sell US$303,284.50 in the next 6 weeks
# Store 797 will sell US$195,151.66 in the next 6 weeks
# Store 799 will sell US$387,391.50 in the next 6 weeks
# Store 800 will sell US$192,760.41 in the next 6 weeks
# Store 801 will sell US$208,153.56 in the next 6 weeks
# Store 802 will sell US$266,855.78 in the next 6 weeks
# Store 803 will sell US$238,179.62 in the next 6 weeks
# Store 804 will sell US$189,107.57 in the next 6 weeks
# Store 805 will sell US$236,257.66 in the next 6 weeks
# Store 806 will sell US$261,778.50 in the next 6 weeks
# Store 807 will sell US$385,205.51 in the next 6 weeks
# Store 809 will sell US$375,677.60 in the next 6 weeks
# Store 810 will sell US$248,798.06 in the next 6 weeks
# Store 811 will sell US$162,276.49 in the next 6 weeks
# Store 813 will sell US$229,311.18 in the next 6 weeks
# Store 815 will sell US$253,943.80 in the next 6 weeks
# Store 816 will sell US$198,131.13 in the next 6 weeks
# Store 818 will sell US$242,791.83 in the next 6 weeks
# Store 819 will sell US$248,061.66 in the next 6 weeks
# Store 820 will sell US$390,978.28 in the next 6 weeks
# Store 822 will sell US$303,351.65 in the next 6 weeks
# Store 823 will sell US$257,400.63 in the next 6 weeks
# Store 824 will sell US$278,440.92 in the next 6 weeks
# Store 825 will sell US$207,116.29 in the next 6 weeks
# Store 826 will sell US$355,977.66 in the next 6 weeks
# Store 829 will sell US$230,184.73 in the next 6 weeks
# Store 831 will sell US$467,778.29 in the next 6 weeks
# Store 832 will sell US$254,306.00 in the next 6 weeks
# Store 833 will sell US$215,721.48 in the next 6 weeks
# Store 835 will sell US$222,352.78 in the next 6 weeks
# Store 837 will sell US$173,141.14 in the next 6 weeks
# Store 840 will sell US$282,300.15 in the next 6 weeks
# Store 842 will sell US$710,886.75 in the next 6 weeks
# Store 844 will sell US$166,076.39 in the next 6 weeks
# Store 845 will sell US$193,713.14 in the next 6 weeks
# Store 846 will sell US$371,957.67 in the next 6 weeks
# Store 847 will sell US$272,268.30 in the next 6 weeks
# Store 848 will sell US$275,247.99 in the next 6 weeks
# Store 849 will sell US$323,466.67 in the next 6 weeks
# Store 850 will sell US$248,634.66 in the next 6 weeks
# Store 851 will sell US$227,096.31 in the next 6 weeks
# Store 852 will sell US$177,421.12 in the next 6 weeks
# Store 853 will sell US$368,365.58 in the next 6 weeks
# Store 855 will sell US$224,401.19 in the next 6 weeks
# Store 856 will sell US$277,011.49 in the next 6 weeks
# Store 857 will sell US$295,584.76 in the next 6 weeks
# Store 858 will sell US$203,989.49 in the next 6 weeks
# Store 859 will sell US$301,833.26 in the next 6 weeks
# Store 860 will sell US$250,983.70 in the next 6 weeks
# Store 861 will sell US$159,599.51 in the next 6 weeks
# Store 862 will sell US$340,661.78 in the next 6 weeks
# Store 863 will sell US$376,075.40 in the next 6 weeks
# Store 864 will sell US$170,423.19 in the next 6 weeks
# Store 865 will sell US$314,568.16 in the next 6 weeks
# Store 866 will sell US$275,134.15 in the next 6 weeks
# Store 867 will sell US$218,176.74 in the next 6 weeks
# Store 868 will sell US$377,141.68 in the next 6 weeks
# Store 871 will sell US$268,869.83 in the next 6 weeks
# Store 872 will sell US$316,148.30 in the next 6 weeks
# Store 874 will sell US$188,923.81 in the next 6 weeks
# Store 875 will sell US$205,992.05 in the next 6 weeks
# Store 877 will sell US$265,571.10 in the next 6 weeks
# Store 879 will sell US$137,333.81 in the next 6 weeks
# Store 880 will sell US$310,909.68 in the next 6 weeks
# Store 881 will sell US$174,692.49 in the next 6 weeks
# Store 882 will sell US$244,655.35 in the next 6 weeks
# Store 883 will sell US$190,576.13 in the next 6 weeks
# Store 884 will sell US$248,927.72 in the next 6 weeks
# Store 885 will sell US$247,618.90 in the next 6 weeks
# Store 886 will sell US$266,509.56 in the next 6 weeks
# Store 887 will sell US$268,511.03 in the next 6 weeks
# Store 888 will sell US$327,430.74 in the next 6 weeks
# Store 890 will sell US$224,313.42 in the next 6 weeks
# Store 891 will sell US$305,466.30 in the next 6 weeks
# Store 893 will sell US$244,161.94 in the next 6 weeks
# Store 894 will sell US$320,635.34 in the next 6 weeks
# Store 895 will sell US$374,441.86 in the next 6 weeks
# Store 896 will sell US$286,414.46 in the next 6 weeks
# Store 897 will sell US$141,181.76 in the next 6 weeks
# Store 900 will sell US$245,334.97 in the next 6 weeks
# Store 901 will sell US$283,848.78 in the next 6 weeks
# Store 902 will sell US$189,418.62 in the next 6 weeks
# Store 903 will sell US$405,284.98 in the next 6 weeks
# Store 904 will sell US$226,063.28 in the next 6 weeks
# Store 905 will sell US$277,466.67 in the next 6 weeks
# Store 906 will sell US$399,012.77 in the next 6 weeks
# Store 907 will sell US$272,007.72 in the next 6 weeks
# Store 908 will sell US$161,622.64 in the next 6 weeks
# Store 909 will sell US$394,466.69 in the next 6 weeks
# Store 911 will sell US$398,740.79 in the next 6 weeks
# Store 912 will sell US$235,241.00 in the next 6 weeks
# Store 913 will sell US$332,517.66 in the next 6 weeks
# Store 914 will sell US$377,209.10 in the next 6 weeks
# Store 915 will sell US$251,134.29 in the next 6 weeks
# Store 916 will sell US$224,936.47 in the next 6 weeks
# Store 917 will sell US$260,615.38 in the next 6 weeks
# Store 919 will sell US$207,534.26 in the next 6 weeks
# Store 920 will sell US$235,823.25 in the next 6 weeks
# Store 922 will sell US$290,451.40 in the next 6 weeks
# Store 924 will sell US$186,014.85 in the next 6 weeks
# Store 925 will sell US$268,271.69 in the next 6 weeks
# Store 926 will sell US$292,181.26 in the next 6 weeks
# Store 927 will sell US$257,656.02 in the next 6 weeks
# Store 928 will sell US$324,468.75 in the next 6 weeks
# Store 929 will sell US$249,948.30 in the next 6 weeks
# Store 930 will sell US$278,898.46 in the next 6 weeks
# Store 931 will sell US$181,044.58 in the next 6 weeks
# Store 932 will sell US$291,697.77 in the next 6 weeks
# Store 934 will sell US$263,771.05 in the next 6 weeks
# Store 935 will sell US$238,267.76 in the next 6 weeks
# Store 936 will sell US$273,119.57 in the next 6 weeks
# Store 937 will sell US$293,720.09 in the next 6 weeks
# Store 938 will sell US$363,365.56 in the next 6 weeks
# Store 939 will sell US$245,644.13 in the next 6 weeks
# Store 941 will sell US$208,437.54 in the next 6 weeks
# Store 942 will sell US$247,682.13 in the next 6 weeks
# Store 943 will sell US$286,973.86 in the next 6 weeks
# Store 944 will sell US$254,777.92 in the next 6 weeks
# Store 945 will sell US$183,700.18 in the next 6 weeks
# Store 946 will sell US$174,021.39 in the next 6 weeks
# Store 947 will sell US$313,429.75 in the next 6 weeks
# Store 948 will sell US$349,437.86 in the next 6 weeks
# Store 950 will sell US$216,374.03 in the next 6 weeks
# Store 951 will sell US$320,914.80 in the next 6 weeks
# Store 952 will sell US$264,116.17 in the next 6 weeks
# Store 954 will sell US$267,791.66 in the next 6 weeks
# Store 955 will sell US$214,932.64 in the next 6 weeks
# Store 956 will sell US$139,838.07 in the next 6 weeks
# Store 960 will sell US$266,200.65 in the next 6 weeks
# Store 961 will sell US$269,337.43 in the next 6 weeks
# Store 962 will sell US$265,218.63 in the next 6 weeks
# Store 964 will sell US$365,976.09 in the next 6 weeks
# Store 965 will sell US$338,650.93 in the next 6 weeks
# Store 966 will sell US$190,336.57 in the next 6 weeks
# Store 967 will sell US$330,057.47 in the next 6 weeks
# Store 969 will sell US$159,460.82 in the next 6 weeks
# Store 970 will sell US$125,333.92 in the next 6 weeks
# Store 973 will sell US$300,192.73 in the next 6 weeks
# Store 974 will sell US$433,784.92 in the next 6 weeks
# Store 975 will sell US$296,732.38 in the next 6 weeks
# Store 976 will sell US$275,321.57 in the next 6 weeks
# Store 977 will sell US$179,826.76 in the next 6 weeks
# Store 980 will sell US$269,895.93 in the next 6 weeks
# Store 983 will sell US$358,438.75 in the next 6 weeks
# Store 984 will sell US$237,984.20 in the next 6 weeks
# Store 985 will sell US$320,692.16 in the next 6 weeks
# Store 986 will sell US$201,104.76 in the next 6 weeks
# Store 988 will sell US$192,473.25 in the next 6 weeks
# Store 989 will sell US$201,002.48 in the next 6 weeks
# Store 991 will sell US$224,686.95 in the next 6 weeks
# Store 992 will sell US$216,183.13 in the next 6 weeks
# Store 994 will sell US$190,370.56 in the next 6 weeks
# Store 997 will sell US$197,708.24 in the next 6 weeks
# Store 998 will sell US$174,526.70 in the next 6 weeks
# Store 1000 will sell US$297,717.30 in the next 6 weeks
# Store 1003 will sell US$281,027.78 in the next 6 weeks
# Store 1004 will sell US$207,356.91 in the next 6 weeks
# Store 1005 will sell US$250,553.79 in the next 6 weeks
# Store 1007 will sell US$283,534.93 in the next 6 weeks
# Store 1008 will sell US$223,537.69 in the next 6 weeks
# Store 1009 will sell US$207,996.56 in the next 6 weeks
# Store 1010 will sell US$355,131.28 in the next 6 weeks
# Store 1011 will sell US$309,662.08 in the next 6 weeks
# Store 1012 will sell US$233,182.15 in the next 6 weeks
# Store 1013 will sell US$160,362.58 in the next 6 weeks
# Store 1014 will sell US$448,398.12 in the next 6 weeks
# Store 1015 will sell US$247,631.64 in the next 6 weeks
# Store 1016 will sell US$218,469.74 in the next 6 weeks
# Store 1019 will sell US$332,698.40 in the next 6 weeks
# Store 1020 will sell US$287,754.89 in the next 6 weeks
# Store 1022 will sell US$293,683.61 in the next 6 weeks
# Store 1024 will sell US$250,027.73 in the next 6 weeks
# Store 1025 will sell US$285,010.50 in the next 6 weeks
# Store 1026 will sell US$383,150.33 in the next 6 weeks
# Store 1027 will sell US$535,890.56 in the next 6 weeks
# Store 1028 will sell US$201,029.08 in the next 6 weeks
# Store 1031 will sell US$186,779.39 in the next 6 weeks
# Store 1036 will sell US$218,223.23 in the next 6 weeks
# Store 1037 will sell US$268,667.16 in the next 6 weeks
# Store 1038 will sell US$233,781.64 in the next 6 weeks
# Store 1039 will sell US$350,863.50 in the next 6 weeks
# Store 1040 will sell US$343,070.43 in the next 6 weeks
# Store 1041 will sell US$241,855.59 in the next 6 weeks
# Store 1042 will sell US$169,912.55 in the next 6 weeks
# Store 1044 will sell US$255,458.62 in the next 6 weeks
# Store 1045 will sell US$389,935.96 in the next 6 weeks
# Store 1047 will sell US$191,064.91 in the next 6 weeks
# Store 1048 will sell US$297,904.25 in the next 6 weeks
# Store 1049 will sell US$157,285.43 in the next 6 weeks
# Store 1050 will sell US$287,892.46 in the next 6 weeks
# Store 1051 will sell US$299,654.86 in the next 6 weeks
# Store 1052 will sell US$284,280.81 in the next 6 weeks
# Store 1053 will sell US$307,278.91 in the next 6 weeks
# Store 1054 will sell US$246,956.82 in the next 6 weeks
# Store 1056 will sell US$191,662.66 in the next 6 weeks
# Store 1057 will sell US$261,637.24 in the next 6 weeks
# Store 1058 will sell US$291,294.79 in the next 6 weeks
# Store 1059 will sell US$337,516.21 in the next 6 weeks
# Store 1060 will sell US$290,227.96 in the next 6 weeks
# Store 1061 will sell US$317,580.05 in the next 6 weeks
# Store 1062 will sell US$252,751.31 in the next 6 weeks
# Store 1063 will sell US$186,878.18 in the next 6 weeks
# Store 1064 will sell US$388,355.01 in the next 6 weeks
# Store 1065 will sell US$172,002.25 in the next 6 weeks
# Store 1066 will sell US$443,937.50 in the next 6 weeks
# Store 1067 will sell US$242,560.35 in the next 6 weeks
# Store 1068 will sell US$189,927.15 in the next 6 weeks
# Store 1070 will sell US$280,814.05 in the next 6 weeks
# Store 1071 will sell US$242,523.30 in the next 6 weeks
# Store 1072 will sell US$248,555.18 in the next 6 weeks
# Store 1073 will sell US$328,716.16 in the next 6 weeks
# Store 1076 will sell US$165,320.98 in the next 6 weeks
# Store 1077 will sell US$177,446.01 in the next 6 weeks
# Store 1078 will sell US$286,089.88 in the next 6 weeks
# Store 1079 will sell US$328,261.78 in the next 6 weeks
# Store 1080 will sell US$373,595.43 in the next 6 weeks
# Store 1083 will sell US$230,690.47 in the next 6 weeks
# Store 1084 will sell US$243,391.11 in the next 6 weeks
# Store 1086 will sell US$243,397.70 in the next 6 weeks
# Store 1087 will sell US$262,289.96 in the next 6 weeks
# Store 1088 will sell US$223,322.80 in the next 6 weeks
# Store 1089 will sell US$409,583.22 in the next 6 weeks
# Store 1091 will sell US$343,937.06 in the next 6 weeks
# Store 1092 will sell US$446,539.74 in the next 6 weeks
# Store 1094 will sell US$197,676.90 in the next 6 weeks
# Store 1096 will sell US$239,981.67 in the next 6 weeks
# Store 1097 will sell US$428,731.56 in the next 6 weeks
# Store 1099 will sell US$370,392.18 in the next 6 weeks
# Store 1100 will sell US$198,563.72 in the next 6 weeks
# Store 1101 will sell US$400,122.23 in the next 6 weeks
# Store 1102 will sell US$255,764.28 in the next 6 weeks
# Store 1103 will sell US$224,051.16 in the next 6 weeks
# Store 1104 will sell US$205,139.57 in the next 6 weeks
# Store 1105 will sell US$218,364.55 in the next 6 weeks
# Store 1106 will sell US$211,827.20 in the next 6 weeks
# Store 1107 will sell US$242,884.92 in the next 6 weeks
# Store 1109 will sell US$199,799.95 in the next 6 weeks
# Store 1111 will sell US$205,396.26 in the next 6 weeks
# Store 1112 will sell US$367,147.95 in the next 6 weeks
# Store 1113 will sell US$270,935.96 in the next 6 weeks
# Store 1114 will sell US$856,504.20 in the next 6 weeks
# Store 1115 will sell US$278,272.88 in the next 6 weeks

# %%
d1.head()
# Out:
#    store  day_of_week                      date  open  promo state_holiday  school_holiday store_type assortment  competition_distance  competition_open_since_month  competition_open_since_year  promo2  promo2_since_week  promo2_since_year   promo_interval month_map  is_promo  year  month  day  week_of_year year_week         competition_since  competition_since_month               promo_since  promo_time_week  prediction
# 0     22            4  2015-09-17T00:00:00.000Z 1.000      1   regular_day               0          a      basic              1040.000                             9                         2015       1                 22               2012  Jan,Apr,Jul,Oct      Sept         0  2015      9   17            38   2015-37  2015-09-01T00:00:00.000Z                        0  2012-05-21T00:00:00.000Z              173    4724.852
# 1     23            4  2015-09-17T00:00:00.000Z 1.000      1   regular_day               0          d      basic              4060.000                             8                         2005       0                 38               2015                0      Sept         0  2015      9   17            38   2015-37  2005-08-01T00:00:00.000Z                      123  2015-09-14T00:00:00.000Z                0    6058.121
# 2     24            4  2015-09-17T00:00:00.000Z 1.000      1   regular_day               0          a   extended              4590.000                             3                         2000       1                 40               2011  Jan,Apr,Jul,Oct      Sept         0  2015      9   17            38   2015-37  2000-03-01T00:00:00.000Z                      189  2011-09-26T00:00:00.000Z              207    9796.460
# 3     22            3  2015-09-16T00:00:00.000Z 1.000      1   regular_day               0          a      basic              1040.000                             9                         2015       1                 22               2012  Jan,Apr,Jul,Oct      Sept         0  2015      9   16            38   2015-37  2015-09-01T00:00:00.000Z                        0  2012-05-21T00:00:00.000Z              173    4787.216
# 4     23            3  2015-09-16T00:00:00.000Z 1.000      1   regular_day               0          d      basic              4060.000                             8                         2005       0                 38               2015                0      Sept         0  2015      9   16            38   2015-37  2005-08-01T00:00:00.000Z                      123  2015-09-14T00:00:00.000Z                0    6054.037
